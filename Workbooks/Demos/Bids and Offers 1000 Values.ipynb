# %%
# --------------------------------------------------------------------------------------
# Appendix of Libraries/Packages in Order of Use: Equilibrium Bids and Offers Algorithm 
# --------------------------------------------------------------------------------------

from ipywidgets import widgets, VBox, Button, Output
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
from scipy.optimize import root_scalar
from scipy.integrate import quad
from scipy.interpolate import interp1d
import warnings
from scipy.integrate import IntegrationWarning
warnings.simplefilter("ignore", IntegrationWarning)
import pandas as pd
import pickle
from pathlib import Path

# %%
# -------------------------------------------------------------------------------------------
# Data Generating Process for the k-DA (Section 4.1: The Model, and Data Generating Process)
# Generate vb, vs, k, prices, v_lower, c_upper
# -------------------------------------------------------------------------------------------

from ipywidgets import widgets, VBox, Button, Output
from IPython.display import display
import numpy as np

vb, vs = [], []
prices = (0.0, 1.0)
k = 0.5
v_lower = None  
c_upper = None  

# --------------------------------------------------------------
# Sorting Buyer and Seller Valuations According to N (num_vals)
# --------------------------------------------------------------

def generate_values(num_vals):
    return np.linspace(0, 1, num_vals).tolist()

# --------------------------------------------------------------------
# Algorithmic Formalization of Definition 1 (Discrete Valuation Grid)
# --------------------------------------------------------------------

def get_game(num_vals):
    global vb, vs, prices
    base_values = generate_values(num_vals)
    vb = sorted(base_values)         # ------------------
    vs = sorted(base_values.copy())  # Explicit symmetry
    prices = (0.0, 1.0)              # ------------------
    return vs, vb, prices

default_output = Output()

def calculate(b):
    default_output.clear_output()
    num_vals = num_vals_widget.value
    k_value = k_slider.value
    vs, vb, prices = get_game(num_vals)
    
    global v_lower, c_upper
    
    # -----------------------------------------
    # Algorithmic Formalization of Definiton 2
    # -----------------------------------------
    
    E = [v for v in vb if 0.1 <= v <= 0.25]
    v_lower = np.random.choice(E) if E else 0.173
    
    # -----------------------------
    # Explicit Symmetry of c_upper
    # -----------------------------
    
    c_upper = 1 - v_lower
    
    with default_output:
        print(f"Number of Possible Values: {num_vals}, k: {k_value:.3f}")
        print()
        print(f"Buyers: {[f'{v:.5f}' for v in vb]}")
        print(f"Sellers: {[f'{c:.5f}' for c in vs]}")
        print()
        print(f"Trading Range: [{v_lower:.5f}, {c_upper:.5f}]")

        
# -----------------------------------------------
# Print Parameter Selection Mechanism (Figure 1)
# -----------------------------------------------

num_vals_widget = widgets.IntSlider(
    value=5, min=5, max=1000, step=1, description='Num Values:'
)
k_slider = widgets.FloatSlider(value=k, min=0, max=1, step=0.001, description='k:')
print("MUST CLICK CALCULATE BUTTON AFTER SETTING PARAMETERS TO RECEIVE VALUES")
print("FOR HIGH OR LOW K (ie k >= .75 or k <= .25) MUST ALSO HAVE SUFFICIENT NUMBER OF POSSIBLE VALUATIONS")
calculate_button = Button(description="Calculate")
calculate_button.on_click(calculate)

default_ui = VBox([num_vals_widget, k_slider, calculate_button, default_output])
display(default_ui)
# Out:
# MUST CLICK CALCULATE BUTTON AFTER SETTING PARAMETERS TO RECEIVE VALUES
# FOR HIGH OR LOW K (ie k >= .75 or k <= .25) MUST ALSO HAVE SUFFICIENT NUMBER OF POSSIBLE VALUATIONS
# VBox(children=(IntSlider(value=5, description='Num Values:', max=1000, min=5), FloatSlider(value=0.5, descript…

# %%
# --------------------------------------------------------------------
# Calculation of "Serious" Intervals for Buyer and Seller bids/offers
# --------------------------------------------------------------------

global vb_serious_interval, vs_serious_interval, serious_values_interval

# ------------------------------------------------------------------------------------------
# Algorithmic Formalization of the Contraints in Defintion 3 (Eligible Bids and Offers Intervals)
# ------------------------------------------------------------------------------------------

vb_serious_interval = (v_lower, 1.0)
vs_serious_interval = (0.0, c_upper)
serious_values_interval = (v_lower, c_upper)

# ------------------
# v_lower in [0, 1]
# ------------------

def buyer_possible_bids(v):
    """For a buyer with valuation v, return bidding interval or message"""
    if v < vb_serious_interval[0]:
        return "not in serious bids (below threshold)"
    
    interval = (vb_serious_interval[0], v)
    if interval[0] == interval[1]:
        return f"[{interval[0]:.5f}] (Only Possible Bid)"
    return interval

# ------------------
# c_upper in [0, 1]
# ------------------

def seller_possible_offers(v):
    """For a seller with valuation v, return offering interval or message"""
    if v > serious_values_interval[1]:
        return "not in serious offers (above threshold)"
    
    interval = (v, vs_serious_interval[1])
    if interval[0] == interval[1]:
        return f"[{interval[0]:.5f}] (Only Possible Offer)"
    return interval

# ---------------------------------------------------------------
# Restrict "Serious" Bids and Offers for Valuations in vb and vs
# ---------------------------------------------------------------

possible_bids = {v: buyer_possible_bids(v) for v in vb}
possible_offers = {v: seller_possible_offers(v) for v in vs}

# ---------------------------------------------------------------------
# Print "Serious Trading Intervals" (Figure 2) 
# ---------------------------------------------------------------------

print("\n" + "="*55)
print(" SERIOUS TRADING INTERVALS ".center(55, '='))
print("="*55)
print(f"Buyer Serious Interval: [{vb_serious_interval[0]:.5f}, {vb_serious_interval[1]:.5f}]")
print(f"Seller Serious Interval: [{vs_serious_interval[0]:.5f}, {vs_serious_interval[1]:.5f}]")
print(f"Trading Overlap: [{serious_values_interval[0]:.5f}, {serious_values_interval[1]:.5f}]")

# -------------------------------------------------
# Final Overlap Percentage 100(c_upper - v_lower)%
# -------------------------------------------------

print(f"→ {100*(serious_values_interval[1]-serious_values_interval[0]):.1f}% of price continuum\n")

# ----------------------------------------
# Print "Buyer Bidding Ranges" (Figure 2)
# ----------------------------------------

print("\n" + "="*55)
print(" BUYER BIDDING RANGES ".center(55, '='))
print("="*55)
for v in vb: 
    bid = possible_bids[v]
    if isinstance(bid, tuple):
        print(f"Buyer {v:.5f} | Bids: [{bid[0]:.5f}, {bid[1]:.5f}]")
    elif "(exact" in bid:
        print(f"Buyer {v:.5f} | {bid}")
    else:
        print(f"Buyer {v:.5f} | {bid}")

# ------------------------------------------
# Print "Seller Offering Ranges" (Figure 2)
# ------------------------------------------

print("\n" + "="*55)
print(" SELLER OFFERING RANGES ".center(55, '='))
print("="*55)
for v in vs:
    offer = possible_offers[v]
    if isinstance(offer, tuple):
        print(f"Seller {v:.5f} | Offers: [{offer[0]:.5f}, {offer[1]:.5f}]")
    elif "(exact" in offer:
        print(f"Seller {v:.5f} | {offer}")
    else:
        print(f"Seller {v:.5f} | {offer}")
# Out:
# =======================================================
# ============== SERIOUS TRADING INTERVALS ==============
# =======================================================
# Buyer Serious Interval: [0.24825, 1.00000]
# Seller Serious Interval: [0.00000, 0.75175]
# Trading Overlap: [0.24825, 0.75175]
# → 50.4% of price continuum
#
#
# =======================================================
# ================= BUYER BIDDING RANGES ================
# =======================================================
# Buyer 0.00000 | not in serious bids (below threshold)
# Buyer 0.00100 | not in serious bids (below threshold)
# Buyer 0.00200 | not in serious bids (below threshold)
# Buyer 0.00300 | not in serious bids (below threshold)
# Buyer 0.00400 | not in serious bids (below threshold)
# Buyer 0.00501 | not in serious bids (below threshold)
# Buyer 0.00601 | not in serious bids (below threshold)
# Buyer 0.00701 | not in serious bids (below threshold)
# Buyer 0.00801 | not in serious bids (below threshold)
# Buyer 0.00901 | not in serious bids (below threshold)
# Buyer 0.01001 | not in serious bids (below threshold)
# Buyer 0.01101 | not in serious bids (below threshold)
# Buyer 0.01201 | not in serious bids (below threshold)
# Buyer 0.01301 | not in serious bids (below threshold)
# Buyer 0.01401 | not in serious bids (below threshold)
# Buyer 0.01502 | not in serious bids (below threshold)
# Buyer 0.01602 | not in serious bids (below threshold)
# Buyer 0.01702 | not in serious bids (below threshold)
# Buyer 0.01802 | not in serious bids (below threshold)
# Buyer 0.01902 | not in serious bids (below threshold)
# Buyer 0.02002 | not in serious bids (below threshold)
# Buyer 0.02102 | not in serious bids (below threshold)
# Buyer 0.02202 | not in serious bids (below threshold)
# Buyer 0.02302 | not in serious bids (below threshold)
# Buyer 0.02402 | not in serious bids (below threshold)
# Buyer 0.02503 | not in serious bids (below threshold)
# Buyer 0.02603 | not in serious bids (below threshold)
# Buyer 0.02703 | not in serious bids (below threshold)
# Buyer 0.02803 | not in serious bids (below threshold)
# Buyer 0.02903 | not in serious bids (below threshold)
# Buyer 0.03003 | not in serious bids (below threshold)
# Buyer 0.03103 | not in serious bids (below threshold)
# Buyer 0.03203 | not in serious bids (below threshold)
# Buyer 0.03303 | not in serious bids (below threshold)
# Buyer 0.03403 | not in serious bids (below threshold)
# Buyer 0.03504 | not in serious bids (below threshold)
# Buyer 0.03604 | not in serious bids (below threshold)
# Buyer 0.03704 | not in serious bids (below threshold)
# Buyer 0.03804 | not in serious bids (below threshold)
# Buyer 0.03904 | not in serious bids (below threshold)
# Buyer 0.04004 | not in serious bids (below threshold)
# Buyer 0.04104 | not in serious bids (below threshold)
# Buyer 0.04204 | not in serious bids (below threshold)
# Buyer 0.04304 | not in serious bids (below threshold)
# Buyer 0.04404 | not in serious bids (below threshold)
# Buyer 0.04505 | not in serious bids (below threshold)
# Buyer 0.04605 | not in serious bids (below threshold)
# Buyer 0.04705 | not in serious bids (below threshold)
# Buyer 0.04805 | not in serious bids (below threshold)
# Buyer 0.04905 | not in serious bids (below threshold)
# Buyer 0.05005 | not in serious bids (below threshold)
# Buyer 0.05105 | not in serious bids (below threshold)
# Buyer 0.05205 | not in serious bids (below threshold)
# Buyer 0.05305 | not in serious bids (below threshold)
# Buyer 0.05405 | not in serious bids (below threshold)
# Buyer 0.05506 | not in serious bids (below threshold)
# Buyer 0.05606 | not in serious bids (below threshold)
# Buyer 0.05706 | not in serious bids (below threshold)
# Buyer 0.05806 | not in serious bids (below threshold)
# Buyer 0.05906 | not in serious bids (below threshold)
# Buyer 0.06006 | not in serious bids (below threshold)
# Buyer 0.06106 | not in serious bids (below threshold)
# Buyer 0.06206 | not in serious bids (below threshold)
# Buyer 0.06306 | not in serious bids (below threshold)
# Buyer 0.06406 | not in serious bids (below threshold)
# Buyer 0.06507 | not in serious bids (below threshold)
# Buyer 0.06607 | not in serious bids (below threshold)
# Buyer 0.06707 | not in serious bids (below threshold)
# Buyer 0.06807 | not in serious bids (below threshold)
# Buyer 0.06907 | not in serious bids (below threshold)
# Buyer 0.07007 | not in serious bids (below threshold)
# Buyer 0.07107 | not in serious bids (below threshold)
# Buyer 0.07207 | not in serious bids (below threshold)
# Buyer 0.07307 | not in serious bids (below threshold)
# Buyer 0.07407 | not in serious bids (below threshold)
# Buyer 0.07508 | not in serious bids (below threshold)
# Buyer 0.07608 | not in serious bids (below threshold)
# Buyer 0.07708 | not in serious bids (below threshold)
# Buyer 0.07808 | not in serious bids (below threshold)
# Buyer 0.07908 | not in serious bids (below threshold)
# Buyer 0.08008 | not in serious bids (below threshold)
# Buyer 0.08108 | not in serious bids (below threshold)
# Buyer 0.08208 | not in serious bids (below threshold)
# Buyer 0.08308 | not in serious bids (below threshold)
# Buyer 0.08408 | not in serious bids (below threshold)
# Buyer 0.08509 | not in serious bids (below threshold)
# Buyer 0.08609 | not in serious bids (below threshold)
# Buyer 0.08709 | not in serious bids (below threshold)
# Buyer 0.08809 | not in serious bids (below threshold)
# Buyer 0.08909 | not in serious bids (below threshold)
# Buyer 0.09009 | not in serious bids (below threshold)
# Buyer 0.09109 | not in serious bids (below threshold)
# Buyer 0.09209 | not in serious bids (below threshold)
# Buyer 0.09309 | not in serious bids (below threshold)
# Buyer 0.09409 | not in serious bids (below threshold)
# Buyer 0.09510 | not in serious bids (below threshold)
# Buyer 0.09610 | not in serious bids (below threshold)
# Buyer 0.09710 | not in serious bids (below threshold)
# Buyer 0.09810 | not in serious bids (below threshold)
# Buyer 0.09910 | not in serious bids (below threshold)
# Buyer 0.10010 | not in serious bids (below threshold)
# Buyer 0.10110 | not in serious bids (below threshold)
# Buyer 0.10210 | not in serious bids (below threshold)
# Buyer 0.10310 | not in serious bids (below threshold)
# Buyer 0.10410 | not in serious bids (below threshold)
# Buyer 0.10511 | not in serious bids (below threshold)
# Buyer 0.10611 | not in serious bids (below threshold)
# Buyer 0.10711 | not in serious bids (below threshold)
# Buyer 0.10811 | not in serious bids (below threshold)
# Buyer 0.10911 | not in serious bids (below threshold)
# Buyer 0.11011 | not in serious bids (below threshold)
# Buyer 0.11111 | not in serious bids (below threshold)
# Buyer 0.11211 | not in serious bids (below threshold)
# Buyer 0.11311 | not in serious bids (below threshold)
# Buyer 0.11411 | not in serious bids (below threshold)
# Buyer 0.11512 | not in serious bids (below threshold)
# Buyer 0.11612 | not in serious bids (below threshold)
# Buyer 0.11712 | not in serious bids (below threshold)
# Buyer 0.11812 | not in serious bids (below threshold)
# Buyer 0.11912 | not in serious bids (below threshold)
# Buyer 0.12012 | not in serious bids (below threshold)
# Buyer 0.12112 | not in serious bids (below threshold)
# Buyer 0.12212 | not in serious bids (below threshold)
# Buyer 0.12312 | not in serious bids (below threshold)
# Buyer 0.12412 | not in serious bids (below threshold)
# Buyer 0.12513 | not in serious bids (below threshold)
# Buyer 0.12613 | not in serious bids (below threshold)
# Buyer 0.12713 | not in serious bids (below threshold)
# Buyer 0.12813 | not in serious bids (below threshold)
# Buyer 0.12913 | not in serious bids (below threshold)
# Buyer 0.13013 | not in serious bids (below threshold)
# Buyer 0.13113 | not in serious bids (below threshold)
# Buyer 0.13213 | not in serious bids (below threshold)
# Buyer 0.13313 | not in serious bids (below threshold)
# Buyer 0.13413 | not in serious bids (below threshold)
# Buyer 0.13514 | not in serious bids (below threshold)
# Buyer 0.13614 | not in serious bids (below threshold)
# Buyer 0.13714 | not in serious bids (below threshold)
# Buyer 0.13814 | not in serious bids (below threshold)
# Buyer 0.13914 | not in serious bids (below threshold)
# Buyer 0.14014 | not in serious bids (below threshold)
# Buyer 0.14114 | not in serious bids (below threshold)
# Buyer 0.14214 | not in serious bids (below threshold)
# Buyer 0.14314 | not in serious bids (below threshold)
# Buyer 0.14414 | not in serious bids (below threshold)
# Buyer 0.14515 | not in serious bids (below threshold)
# Buyer 0.14615 | not in serious bids (below threshold)
# Buyer 0.14715 | not in serious bids (below threshold)
# Buyer 0.14815 | not in serious bids (below threshold)
# Buyer 0.14915 | not in serious bids (below threshold)
# Buyer 0.15015 | not in serious bids (below threshold)
# Buyer 0.15115 | not in serious bids (below threshold)
# Buyer 0.15215 | not in serious bids (below threshold)
# Buyer 0.15315 | not in serious bids (below threshold)
# Buyer 0.15415 | not in serious bids (below threshold)
# Buyer 0.15516 | not in serious bids (below threshold)
# Buyer 0.15616 | not in serious bids (below threshold)
# Buyer 0.15716 | not in serious bids (below threshold)
# Buyer 0.15816 | not in serious bids (below threshold)
# Buyer 0.15916 | not in serious bids (below threshold)
# Buyer 0.16016 | not in serious bids (below threshold)
# Buyer 0.16116 | not in serious bids (below threshold)
# Buyer 0.16216 | not in serious bids (below threshold)
# Buyer 0.16316 | not in serious bids (below threshold)
# Buyer 0.16416 | not in serious bids (below threshold)
# Buyer 0.16517 | not in serious bids (below threshold)
# Buyer 0.16617 | not in serious bids (below threshold)
# Buyer 0.16717 | not in serious bids (below threshold)
# Buyer 0.16817 | not in serious bids (below threshold)
# Buyer 0.16917 | not in serious bids (below threshold)
# Buyer 0.17017 | not in serious bids (below threshold)
# Buyer 0.17117 | not in serious bids (below threshold)
# Buyer 0.17217 | not in serious bids (below threshold)
# Buyer 0.17317 | not in serious bids (below threshold)
# Buyer 0.17417 | not in serious bids (below threshold)
# Buyer 0.17518 | not in serious bids (below threshold)
# Buyer 0.17618 | not in serious bids (below threshold)
# Buyer 0.17718 | not in serious bids (below threshold)
# Buyer 0.17818 | not in serious bids (below threshold)
# Buyer 0.17918 | not in serious bids (below threshold)
# Buyer 0.18018 | not in serious bids (below threshold)
# Buyer 0.18118 | not in serious bids (below threshold)
# Buyer 0.18218 | not in serious bids (below threshold)
# Buyer 0.18318 | not in serious bids (below threshold)
# Buyer 0.18418 | not in serious bids (below threshold)
# Buyer 0.18519 | not in serious bids (below threshold)
# Buyer 0.18619 | not in serious bids (below threshold)
# Buyer 0.18719 | not in serious bids (below threshold)
# Buyer 0.18819 | not in serious bids (below threshold)
# Buyer 0.18919 | not in serious bids (below threshold)
# Buyer 0.19019 | not in serious bids (below threshold)
# Buyer 0.19119 | not in serious bids (below threshold)
# Buyer 0.19219 | not in serious bids (below threshold)
# Buyer 0.19319 | not in serious bids (below threshold)
# Buyer 0.19419 | not in serious bids (below threshold)
# Buyer 0.19520 | not in serious bids (below threshold)
# Buyer 0.19620 | not in serious bids (below threshold)
# Buyer 0.19720 | not in serious bids (below threshold)
# Buyer 0.19820 | not in serious bids (below threshold)
# Buyer 0.19920 | not in serious bids (below threshold)
# Buyer 0.20020 | not in serious bids (below threshold)
# Buyer 0.20120 | not in serious bids (below threshold)
# Buyer 0.20220 | not in serious bids (below threshold)
# Buyer 0.20320 | not in serious bids (below threshold)
# Buyer 0.20420 | not in serious bids (below threshold)
# Buyer 0.20521 | not in serious bids (below threshold)
# Buyer 0.20621 | not in serious bids (below threshold)
# Buyer 0.20721 | not in serious bids (below threshold)
# Buyer 0.20821 | not in serious bids (below threshold)
# Buyer 0.20921 | not in serious bids (below threshold)
# Buyer 0.21021 | not in serious bids (below threshold)
# Buyer 0.21121 | not in serious bids (below threshold)
# Buyer 0.21221 | not in serious bids (below threshold)
# Buyer 0.21321 | not in serious bids (below threshold)
# Buyer 0.21421 | not in serious bids (below threshold)
# Buyer 0.21522 | not in serious bids (below threshold)
# Buyer 0.21622 | not in serious bids (below threshold)
# Buyer 0.21722 | not in serious bids (below threshold)
# Buyer 0.21822 | not in serious bids (below threshold)
# Buyer 0.21922 | not in serious bids (below threshold)
# Buyer 0.22022 | not in serious bids (below threshold)
# Buyer 0.22122 | not in serious bids (below threshold)
# Buyer 0.22222 | not in serious bids (below threshold)
# Buyer 0.22322 | not in serious bids (below threshold)
# Buyer 0.22422 | not in serious bids (below threshold)
# Buyer 0.22523 | not in serious bids (below threshold)
# Buyer 0.22623 | not in serious bids (below threshold)
# Buyer 0.22723 | not in serious bids (below threshold)
# Buyer 0.22823 | not in serious bids (below threshold)
# Buyer 0.22923 | not in serious bids (below threshold)
# Buyer 0.23023 | not in serious bids (below threshold)
# Buyer 0.23123 | not in serious bids (below threshold)
# Buyer 0.23223 | not in serious bids (below threshold)
# Buyer 0.23323 | not in serious bids (below threshold)
# Buyer 0.23423 | not in serious bids (below threshold)
# Buyer 0.23524 | not in serious bids (below threshold)
# Buyer 0.23624 | not in serious bids (below threshold)
# Buyer 0.23724 | not in serious bids (below threshold)
# Buyer 0.23824 | not in serious bids (below threshold)
# Buyer 0.23924 | not in serious bids (below threshold)
# Buyer 0.24024 | not in serious bids (below threshold)
# Buyer 0.24124 | not in serious bids (below threshold)
# Buyer 0.24224 | not in serious bids (below threshold)
# Buyer 0.24324 | not in serious bids (below threshold)
# Buyer 0.24424 | not in serious bids (below threshold)
# Buyer 0.24525 | not in serious bids (below threshold)
# Buyer 0.24625 | not in serious bids (below threshold)
# Buyer 0.24725 | not in serious bids (below threshold)
# Buyer 0.24825 | [0.24825] (Only Possible Bid)
# Buyer 0.24925 | Bids: [0.24825, 0.24925]
# Buyer 0.25025 | Bids: [0.24825, 0.25025]
# Buyer 0.25125 | Bids: [0.24825, 0.25125]
# Buyer 0.25225 | Bids: [0.24825, 0.25225]
# Buyer 0.25325 | Bids: [0.24825, 0.25325]
# Buyer 0.25425 | Bids: [0.24825, 0.25425]
# Buyer 0.25526 | Bids: [0.24825, 0.25526]
# Buyer 0.25626 | Bids: [0.24825, 0.25626]
# Buyer 0.25726 | Bids: [0.24825, 0.25726]
# Buyer 0.25826 | Bids: [0.24825, 0.25826]
# Buyer 0.25926 | Bids: [0.24825, 0.25926]
# Buyer 0.26026 | Bids: [0.24825, 0.26026]
# Buyer 0.26126 | Bids: [0.24825, 0.26126]
# Buyer 0.26226 | Bids: [0.24825, 0.26226]
# Buyer 0.26326 | Bids: [0.24825, 0.26326]
# Buyer 0.26426 | Bids: [0.24825, 0.26426]
# Buyer 0.26527 | Bids: [0.24825, 0.26527]
# Buyer 0.26627 | Bids: [0.24825, 0.26627]
# Buyer 0.26727 | Bids: [0.24825, 0.26727]
# Buyer 0.26827 | Bids: [0.24825, 0.26827]
# Buyer 0.26927 | Bids: [0.24825, 0.26927]
# Buyer 0.27027 | Bids: [0.24825, 0.27027]
# Buyer 0.27127 | Bids: [0.24825, 0.27127]
# Buyer 0.27227 | Bids: [0.24825, 0.27227]
# Buyer 0.27327 | Bids: [0.24825, 0.27327]
# Buyer 0.27427 | Bids: [0.24825, 0.27427]
# Buyer 0.27528 | Bids: [0.24825, 0.27528]
# Buyer 0.27628 | Bids: [0.24825, 0.27628]
# Buyer 0.27728 | Bids: [0.24825, 0.27728]
# Buyer 0.27828 | Bids: [0.24825, 0.27828]
# Buyer 0.27928 | Bids: [0.24825, 0.27928]
# Buyer 0.28028 | Bids: [0.24825, 0.28028]
# Buyer 0.28128 | Bids: [0.24825, 0.28128]
# Buyer 0.28228 | Bids: [0.24825, 0.28228]
# Buyer 0.28328 | Bids: [0.24825, 0.28328]
# Buyer 0.28428 | Bids: [0.24825, 0.28428]
# Buyer 0.28529 | Bids: [0.24825, 0.28529]
# Buyer 0.28629 | Bids: [0.24825, 0.28629]
# Buyer 0.28729 | Bids: [0.24825, 0.28729]
# Buyer 0.28829 | Bids: [0.24825, 0.28829]
# Buyer 0.28929 | Bids: [0.24825, 0.28929]
# Buyer 0.29029 | Bids: [0.24825, 0.29029]
# Buyer 0.29129 | Bids: [0.24825, 0.29129]
# Buyer 0.29229 | Bids: [0.24825, 0.29229]
# Buyer 0.29329 | Bids: [0.24825, 0.29329]
# Buyer 0.29429 | Bids: [0.24825, 0.29429]
# Buyer 0.29530 | Bids: [0.24825, 0.29530]
# Buyer 0.29630 | Bids: [0.24825, 0.29630]
# Buyer 0.29730 | Bids: [0.24825, 0.29730]
# Buyer 0.29830 | Bids: [0.24825, 0.29830]
# Buyer 0.29930 | Bids: [0.24825, 0.29930]
# Buyer 0.30030 | Bids: [0.24825, 0.30030]
# Buyer 0.30130 | Bids: [0.24825, 0.30130]
# Buyer 0.30230 | Bids: [0.24825, 0.30230]
# Buyer 0.30330 | Bids: [0.24825, 0.30330]
# Buyer 0.30430 | Bids: [0.24825, 0.30430]
# Buyer 0.30531 | Bids: [0.24825, 0.30531]
# Buyer 0.30631 | Bids: [0.24825, 0.30631]
# Buyer 0.30731 | Bids: [0.24825, 0.30731]
# Buyer 0.30831 | Bids: [0.24825, 0.30831]
# Buyer 0.30931 | Bids: [0.24825, 0.30931]
# Buyer 0.31031 | Bids: [0.24825, 0.31031]
# Buyer 0.31131 | Bids: [0.24825, 0.31131]
# Buyer 0.31231 | Bids: [0.24825, 0.31231]
# Buyer 0.31331 | Bids: [0.24825, 0.31331]
# Buyer 0.31431 | Bids: [0.24825, 0.31431]
# Buyer 0.31532 | Bids: [0.24825, 0.31532]
# Buyer 0.31632 | Bids: [0.24825, 0.31632]
# Buyer 0.31732 | Bids: [0.24825, 0.31732]
# Buyer 0.31832 | Bids: [0.24825, 0.31832]
# Buyer 0.31932 | Bids: [0.24825, 0.31932]
# Buyer 0.32032 | Bids: [0.24825, 0.32032]
# Buyer 0.32132 | Bids: [0.24825, 0.32132]
# Buyer 0.32232 | Bids: [0.24825, 0.32232]
# Buyer 0.32332 | Bids: [0.24825, 0.32332]
# Buyer 0.32432 | Bids: [0.24825, 0.32432]
# Buyer 0.32533 | Bids: [0.24825, 0.32533]
# Buyer 0.32633 | Bids: [0.24825, 0.32633]
# Buyer 0.32733 | Bids: [0.24825, 0.32733]
# Buyer 0.32833 | Bids: [0.24825, 0.32833]
# Buyer 0.32933 | Bids: [0.24825, 0.32933]
# Buyer 0.33033 | Bids: [0.24825, 0.33033]
# Buyer 0.33133 | Bids: [0.24825, 0.33133]
# Buyer 0.33233 | Bids: [0.24825, 0.33233]
# Buyer 0.33333 | Bids: [0.24825, 0.33333]
# Buyer 0.33433 | Bids: [0.24825, 0.33433]
# Buyer 0.33534 | Bids: [0.24825, 0.33534]
# Buyer 0.33634 | Bids: [0.24825, 0.33634]
# Buyer 0.33734 | Bids: [0.24825, 0.33734]
# Buyer 0.33834 | Bids: [0.24825, 0.33834]
# Buyer 0.33934 | Bids: [0.24825, 0.33934]
# Buyer 0.34034 | Bids: [0.24825, 0.34034]
# Buyer 0.34134 | Bids: [0.24825, 0.34134]
# Buyer 0.34234 | Bids: [0.24825, 0.34234]
# Buyer 0.34334 | Bids: [0.24825, 0.34334]
# Buyer 0.34434 | Bids: [0.24825, 0.34434]
# Buyer 0.34535 | Bids: [0.24825, 0.34535]
# Buyer 0.34635 | Bids: [0.24825, 0.34635]
# Buyer 0.34735 | Bids: [0.24825, 0.34735]
# Buyer 0.34835 | Bids: [0.24825, 0.34835]
# Buyer 0.34935 | Bids: [0.24825, 0.34935]
# Buyer 0.35035 | Bids: [0.24825, 0.35035]
# Buyer 0.35135 | Bids: [0.24825, 0.35135]
# Buyer 0.35235 | Bids: [0.24825, 0.35235]
# Buyer 0.35335 | Bids: [0.24825, 0.35335]
# Buyer 0.35435 | Bids: [0.24825, 0.35435]
# Buyer 0.35536 | Bids: [0.24825, 0.35536]
# Buyer 0.35636 | Bids: [0.24825, 0.35636]
# Buyer 0.35736 | Bids: [0.24825, 0.35736]
# Buyer 0.35836 | Bids: [0.24825, 0.35836]
# Buyer 0.35936 | Bids: [0.24825, 0.35936]
# Buyer 0.36036 | Bids: [0.24825, 0.36036]
# Buyer 0.36136 | Bids: [0.24825, 0.36136]
# Buyer 0.36236 | Bids: [0.24825, 0.36236]
# Buyer 0.36336 | Bids: [0.24825, 0.36336]
# Buyer 0.36436 | Bids: [0.24825, 0.36436]
# Buyer 0.36537 | Bids: [0.24825, 0.36537]
# Buyer 0.36637 | Bids: [0.24825, 0.36637]
# Buyer 0.36737 | Bids: [0.24825, 0.36737]
# Buyer 0.36837 | Bids: [0.24825, 0.36837]
# Buyer 0.36937 | Bids: [0.24825, 0.36937]
# Buyer 0.37037 | Bids: [0.24825, 0.37037]
# Buyer 0.37137 | Bids: [0.24825, 0.37137]
# Buyer 0.37237 | Bids: [0.24825, 0.37237]
# Buyer 0.37337 | Bids: [0.24825, 0.37337]
# Buyer 0.37437 | Bids: [0.24825, 0.37437]
# Buyer 0.37538 | Bids: [0.24825, 0.37538]
# Buyer 0.37638 | Bids: [0.24825, 0.37638]
# Buyer 0.37738 | Bids: [0.24825, 0.37738]
# Buyer 0.37838 | Bids: [0.24825, 0.37838]
# Buyer 0.37938 | Bids: [0.24825, 0.37938]
# Buyer 0.38038 | Bids: [0.24825, 0.38038]
# Buyer 0.38138 | Bids: [0.24825, 0.38138]
# Buyer 0.38238 | Bids: [0.24825, 0.38238]
# Buyer 0.38338 | Bids: [0.24825, 0.38338]
# Buyer 0.38438 | Bids: [0.24825, 0.38438]
# Buyer 0.38539 | Bids: [0.24825, 0.38539]
# Buyer 0.38639 | Bids: [0.24825, 0.38639]
# Buyer 0.38739 | Bids: [0.24825, 0.38739]
# Buyer 0.38839 | Bids: [0.24825, 0.38839]
# Buyer 0.38939 | Bids: [0.24825, 0.38939]
# Buyer 0.39039 | Bids: [0.24825, 0.39039]
# Buyer 0.39139 | Bids: [0.24825, 0.39139]
# Buyer 0.39239 | Bids: [0.24825, 0.39239]
# Buyer 0.39339 | Bids: [0.24825, 0.39339]
# Buyer 0.39439 | Bids: [0.24825, 0.39439]
# Buyer 0.39540 | Bids: [0.24825, 0.39540]
# Buyer 0.39640 | Bids: [0.24825, 0.39640]
# Buyer 0.39740 | Bids: [0.24825, 0.39740]
# Buyer 0.39840 | Bids: [0.24825, 0.39840]
# Buyer 0.39940 | Bids: [0.24825, 0.39940]
# Buyer 0.40040 | Bids: [0.24825, 0.40040]
# Buyer 0.40140 | Bids: [0.24825, 0.40140]
# Buyer 0.40240 | Bids: [0.24825, 0.40240]
# Buyer 0.40340 | Bids: [0.24825, 0.40340]
# Buyer 0.40440 | Bids: [0.24825, 0.40440]
# Buyer 0.40541 | Bids: [0.24825, 0.40541]
# Buyer 0.40641 | Bids: [0.24825, 0.40641]
# Buyer 0.40741 | Bids: [0.24825, 0.40741]
# Buyer 0.40841 | Bids: [0.24825, 0.40841]
# Buyer 0.40941 | Bids: [0.24825, 0.40941]
# Buyer 0.41041 | Bids: [0.24825, 0.41041]
# Buyer 0.41141 | Bids: [0.24825, 0.41141]
# Buyer 0.41241 | Bids: [0.24825, 0.41241]
# Buyer 0.41341 | Bids: [0.24825, 0.41341]
# Buyer 0.41441 | Bids: [0.24825, 0.41441]
# Buyer 0.41542 | Bids: [0.24825, 0.41542]
# Buyer 0.41642 | Bids: [0.24825, 0.41642]
# Buyer 0.41742 | Bids: [0.24825, 0.41742]
# Buyer 0.41842 | Bids: [0.24825, 0.41842]
# Buyer 0.41942 | Bids: [0.24825, 0.41942]
# Buyer 0.42042 | Bids: [0.24825, 0.42042]
# Buyer 0.42142 | Bids: [0.24825, 0.42142]
# Buyer 0.42242 | Bids: [0.24825, 0.42242]
# Buyer 0.42342 | Bids: [0.24825, 0.42342]
# Buyer 0.42442 | Bids: [0.24825, 0.42442]
# Buyer 0.42543 | Bids: [0.24825, 0.42543]
# Buyer 0.42643 | Bids: [0.24825, 0.42643]
# Buyer 0.42743 | Bids: [0.24825, 0.42743]
# Buyer 0.42843 | Bids: [0.24825, 0.42843]
# Buyer 0.42943 | Bids: [0.24825, 0.42943]
# Buyer 0.43043 | Bids: [0.24825, 0.43043]
# Buyer 0.43143 | Bids: [0.24825, 0.43143]
# Buyer 0.43243 | Bids: [0.24825, 0.43243]
# Buyer 0.43343 | Bids: [0.24825, 0.43343]
# Buyer 0.43443 | Bids: [0.24825, 0.43443]
# Buyer 0.43544 | Bids: [0.24825, 0.43544]
# Buyer 0.43644 | Bids: [0.24825, 0.43644]
# Buyer 0.43744 | Bids: [0.24825, 0.43744]
# Buyer 0.43844 | Bids: [0.24825, 0.43844]
# Buyer 0.43944 | Bids: [0.24825, 0.43944]
# Buyer 0.44044 | Bids: [0.24825, 0.44044]
# Buyer 0.44144 | Bids: [0.24825, 0.44144]
# Buyer 0.44244 | Bids: [0.24825, 0.44244]
# Buyer 0.44344 | Bids: [0.24825, 0.44344]
# Buyer 0.44444 | Bids: [0.24825, 0.44444]
# Buyer 0.44545 | Bids: [0.24825, 0.44545]
# Buyer 0.44645 | Bids: [0.24825, 0.44645]
# Buyer 0.44745 | Bids: [0.24825, 0.44745]
# Buyer 0.44845 | Bids: [0.24825, 0.44845]
# Buyer 0.44945 | Bids: [0.24825, 0.44945]
# Buyer 0.45045 | Bids: [0.24825, 0.45045]
# Buyer 0.45145 | Bids: [0.24825, 0.45145]
# Buyer 0.45245 | Bids: [0.24825, 0.45245]
# Buyer 0.45345 | Bids: [0.24825, 0.45345]
# Buyer 0.45445 | Bids: [0.24825, 0.45445]
# Buyer 0.45546 | Bids: [0.24825, 0.45546]
# Buyer 0.45646 | Bids: [0.24825, 0.45646]
# Buyer 0.45746 | Bids: [0.24825, 0.45746]
# Buyer 0.45846 | Bids: [0.24825, 0.45846]
# Buyer 0.45946 | Bids: [0.24825, 0.45946]
# Buyer 0.46046 | Bids: [0.24825, 0.46046]
# Buyer 0.46146 | Bids: [0.24825, 0.46146]
# Buyer 0.46246 | Bids: [0.24825, 0.46246]
# Buyer 0.46346 | Bids: [0.24825, 0.46346]
# Buyer 0.46446 | Bids: [0.24825, 0.46446]
# Buyer 0.46547 | Bids: [0.24825, 0.46547]
# Buyer 0.46647 | Bids: [0.24825, 0.46647]
# Buyer 0.46747 | Bids: [0.24825, 0.46747]
# Buyer 0.46847 | Bids: [0.24825, 0.46847]
# Buyer 0.46947 | Bids: [0.24825, 0.46947]
# Buyer 0.47047 | Bids: [0.24825, 0.47047]
# Buyer 0.47147 | Bids: [0.24825, 0.47147]
# Buyer 0.47247 | Bids: [0.24825, 0.47247]
# Buyer 0.47347 | Bids: [0.24825, 0.47347]
# Buyer 0.47447 | Bids: [0.24825, 0.47447]
# Buyer 0.47548 | Bids: [0.24825, 0.47548]
# Buyer 0.47648 | Bids: [0.24825, 0.47648]
# Buyer 0.47748 | Bids: [0.24825, 0.47748]
# Buyer 0.47848 | Bids: [0.24825, 0.47848]
# Buyer 0.47948 | Bids: [0.24825, 0.47948]
# Buyer 0.48048 | Bids: [0.24825, 0.48048]
# Buyer 0.48148 | Bids: [0.24825, 0.48148]
# Buyer 0.48248 | Bids: [0.24825, 0.48248]
# Buyer 0.48348 | Bids: [0.24825, 0.48348]
# Buyer 0.48448 | Bids: [0.24825, 0.48448]
# Buyer 0.48549 | Bids: [0.24825, 0.48549]
# Buyer 0.48649 | Bids: [0.24825, 0.48649]
# Buyer 0.48749 | Bids: [0.24825, 0.48749]
# Buyer 0.48849 | Bids: [0.24825, 0.48849]
# Buyer 0.48949 | Bids: [0.24825, 0.48949]
# Buyer 0.49049 | Bids: [0.24825, 0.49049]
# Buyer 0.49149 | Bids: [0.24825, 0.49149]
# Buyer 0.49249 | Bids: [0.24825, 0.49249]
# Buyer 0.49349 | Bids: [0.24825, 0.49349]
# Buyer 0.49449 | Bids: [0.24825, 0.49449]
# Buyer 0.49550 | Bids: [0.24825, 0.49550]
# Buyer 0.49650 | Bids: [0.24825, 0.49650]
# Buyer 0.49750 | Bids: [0.24825, 0.49750]
# Buyer 0.49850 | Bids: [0.24825, 0.49850]
# Buyer 0.49950 | Bids: [0.24825, 0.49950]
# Buyer 0.50050 | Bids: [0.24825, 0.50050]
# Buyer 0.50150 | Bids: [0.24825, 0.50150]
# Buyer 0.50250 | Bids: [0.24825, 0.50250]
# Buyer 0.50350 | Bids: [0.24825, 0.50350]
# Buyer 0.50450 | Bids: [0.24825, 0.50450]
# Buyer 0.50551 | Bids: [0.24825, 0.50551]
# Buyer 0.50651 | Bids: [0.24825, 0.50651]
# Buyer 0.50751 | Bids: [0.24825, 0.50751]
# Buyer 0.50851 | Bids: [0.24825, 0.50851]
# Buyer 0.50951 | Bids: [0.24825, 0.50951]
# Buyer 0.51051 | Bids: [0.24825, 0.51051]
# Buyer 0.51151 | Bids: [0.24825, 0.51151]
# Buyer 0.51251 | Bids: [0.24825, 0.51251]
# Buyer 0.51351 | Bids: [0.24825, 0.51351]
# Buyer 0.51451 | Bids: [0.24825, 0.51451]
# Buyer 0.51552 | Bids: [0.24825, 0.51552]
# Buyer 0.51652 | Bids: [0.24825, 0.51652]
# Buyer 0.51752 | Bids: [0.24825, 0.51752]
# Buyer 0.51852 | Bids: [0.24825, 0.51852]
# Buyer 0.51952 | Bids: [0.24825, 0.51952]
# Buyer 0.52052 | Bids: [0.24825, 0.52052]
# Buyer 0.52152 | Bids: [0.24825, 0.52152]
# Buyer 0.52252 | Bids: [0.24825, 0.52252]
# Buyer 0.52352 | Bids: [0.24825, 0.52352]
# Buyer 0.52452 | Bids: [0.24825, 0.52452]
# Buyer 0.52553 | Bids: [0.24825, 0.52553]
# Buyer 0.52653 | Bids: [0.24825, 0.52653]
# Buyer 0.52753 | Bids: [0.24825, 0.52753]
# Buyer 0.52853 | Bids: [0.24825, 0.52853]
# Buyer 0.52953 | Bids: [0.24825, 0.52953]
# Buyer 0.53053 | Bids: [0.24825, 0.53053]
# Buyer 0.53153 | Bids: [0.24825, 0.53153]
# Buyer 0.53253 | Bids: [0.24825, 0.53253]
# Buyer 0.53353 | Bids: [0.24825, 0.53353]
# Buyer 0.53453 | Bids: [0.24825, 0.53453]
# Buyer 0.53554 | Bids: [0.24825, 0.53554]
# Buyer 0.53654 | Bids: [0.24825, 0.53654]
# Buyer 0.53754 | Bids: [0.24825, 0.53754]
# Buyer 0.53854 | Bids: [0.24825, 0.53854]
# Buyer 0.53954 | Bids: [0.24825, 0.53954]
# Buyer 0.54054 | Bids: [0.24825, 0.54054]
# Buyer 0.54154 | Bids: [0.24825, 0.54154]
# Buyer 0.54254 | Bids: [0.24825, 0.54254]
# Buyer 0.54354 | Bids: [0.24825, 0.54354]
# Buyer 0.54454 | Bids: [0.24825, 0.54454]
# Buyer 0.54555 | Bids: [0.24825, 0.54555]
# Buyer 0.54655 | Bids: [0.24825, 0.54655]
# Buyer 0.54755 | Bids: [0.24825, 0.54755]
# Buyer 0.54855 | Bids: [0.24825, 0.54855]
# Buyer 0.54955 | Bids: [0.24825, 0.54955]
# Buyer 0.55055 | Bids: [0.24825, 0.55055]
# Buyer 0.55155 | Bids: [0.24825, 0.55155]
# Buyer 0.55255 | Bids: [0.24825, 0.55255]
# Buyer 0.55355 | Bids: [0.24825, 0.55355]
# Buyer 0.55455 | Bids: [0.24825, 0.55455]
# Buyer 0.55556 | Bids: [0.24825, 0.55556]
# Buyer 0.55656 | Bids: [0.24825, 0.55656]
# Buyer 0.55756 | Bids: [0.24825, 0.55756]
# Buyer 0.55856 | Bids: [0.24825, 0.55856]
# Buyer 0.55956 | Bids: [0.24825, 0.55956]
# Buyer 0.56056 | Bids: [0.24825, 0.56056]
# Buyer 0.56156 | Bids: [0.24825, 0.56156]
# Buyer 0.56256 | Bids: [0.24825, 0.56256]
# Buyer 0.56356 | Bids: [0.24825, 0.56356]
# Buyer 0.56456 | Bids: [0.24825, 0.56456]
# Buyer 0.56557 | Bids: [0.24825, 0.56557]
# Buyer 0.56657 | Bids: [0.24825, 0.56657]
# Buyer 0.56757 | Bids: [0.24825, 0.56757]
# Buyer 0.56857 | Bids: [0.24825, 0.56857]
# Buyer 0.56957 | Bids: [0.24825, 0.56957]
# Buyer 0.57057 | Bids: [0.24825, 0.57057]
# Buyer 0.57157 | Bids: [0.24825, 0.57157]
# Buyer 0.57257 | Bids: [0.24825, 0.57257]
# Buyer 0.57357 | Bids: [0.24825, 0.57357]
# Buyer 0.57457 | Bids: [0.24825, 0.57457]
# Buyer 0.57558 | Bids: [0.24825, 0.57558]
# Buyer 0.57658 | Bids: [0.24825, 0.57658]
# Buyer 0.57758 | Bids: [0.24825, 0.57758]
# Buyer 0.57858 | Bids: [0.24825, 0.57858]
# Buyer 0.57958 | Bids: [0.24825, 0.57958]
# Buyer 0.58058 | Bids: [0.24825, 0.58058]
# Buyer 0.58158 | Bids: [0.24825, 0.58158]
# Buyer 0.58258 | Bids: [0.24825, 0.58258]
# Buyer 0.58358 | Bids: [0.24825, 0.58358]
# Buyer 0.58458 | Bids: [0.24825, 0.58458]
# Buyer 0.58559 | Bids: [0.24825, 0.58559]
# Buyer 0.58659 | Bids: [0.24825, 0.58659]
# Buyer 0.58759 | Bids: [0.24825, 0.58759]
# Buyer 0.58859 | Bids: [0.24825, 0.58859]
# Buyer 0.58959 | Bids: [0.24825, 0.58959]
# Buyer 0.59059 | Bids: [0.24825, 0.59059]
# Buyer 0.59159 | Bids: [0.24825, 0.59159]
# Buyer 0.59259 | Bids: [0.24825, 0.59259]
# Buyer 0.59359 | Bids: [0.24825, 0.59359]
# Buyer 0.59459 | Bids: [0.24825, 0.59459]
# Buyer 0.59560 | Bids: [0.24825, 0.59560]
# Buyer 0.59660 | Bids: [0.24825, 0.59660]
# Buyer 0.59760 | Bids: [0.24825, 0.59760]
# Buyer 0.59860 | Bids: [0.24825, 0.59860]
# Buyer 0.59960 | Bids: [0.24825, 0.59960]
# Buyer 0.60060 | Bids: [0.24825, 0.60060]
# Buyer 0.60160 | Bids: [0.24825, 0.60160]
# Buyer 0.60260 | Bids: [0.24825, 0.60260]
# Buyer 0.60360 | Bids: [0.24825, 0.60360]
# Buyer 0.60460 | Bids: [0.24825, 0.60460]
# Buyer 0.60561 | Bids: [0.24825, 0.60561]
# Buyer 0.60661 | Bids: [0.24825, 0.60661]
# Buyer 0.60761 | Bids: [0.24825, 0.60761]
# Buyer 0.60861 | Bids: [0.24825, 0.60861]
# Buyer 0.60961 | Bids: [0.24825, 0.60961]
# Buyer 0.61061 | Bids: [0.24825, 0.61061]
# Buyer 0.61161 | Bids: [0.24825, 0.61161]
# Buyer 0.61261 | Bids: [0.24825, 0.61261]
# Buyer 0.61361 | Bids: [0.24825, 0.61361]
# Buyer 0.61461 | Bids: [0.24825, 0.61461]
# Buyer 0.61562 | Bids: [0.24825, 0.61562]
# Buyer 0.61662 | Bids: [0.24825, 0.61662]
# Buyer 0.61762 | Bids: [0.24825, 0.61762]
# Buyer 0.61862 | Bids: [0.24825, 0.61862]
# Buyer 0.61962 | Bids: [0.24825, 0.61962]
# Buyer 0.62062 | Bids: [0.24825, 0.62062]
# Buyer 0.62162 | Bids: [0.24825, 0.62162]
# Buyer 0.62262 | Bids: [0.24825, 0.62262]
# Buyer 0.62362 | Bids: [0.24825, 0.62362]
# Buyer 0.62462 | Bids: [0.24825, 0.62462]
# Buyer 0.62563 | Bids: [0.24825, 0.62563]
# Buyer 0.62663 | Bids: [0.24825, 0.62663]
# Buyer 0.62763 | Bids: [0.24825, 0.62763]
# Buyer 0.62863 | Bids: [0.24825, 0.62863]
# Buyer 0.62963 | Bids: [0.24825, 0.62963]
# Buyer 0.63063 | Bids: [0.24825, 0.63063]
# Buyer 0.63163 | Bids: [0.24825, 0.63163]
# Buyer 0.63263 | Bids: [0.24825, 0.63263]
# Buyer 0.63363 | Bids: [0.24825, 0.63363]
# Buyer 0.63463 | Bids: [0.24825, 0.63463]
# Buyer 0.63564 | Bids: [0.24825, 0.63564]
# Buyer 0.63664 | Bids: [0.24825, 0.63664]
# Buyer 0.63764 | Bids: [0.24825, 0.63764]
# Buyer 0.63864 | Bids: [0.24825, 0.63864]
# Buyer 0.63964 | Bids: [0.24825, 0.63964]
# Buyer 0.64064 | Bids: [0.24825, 0.64064]
# Buyer 0.64164 | Bids: [0.24825, 0.64164]
# Buyer 0.64264 | Bids: [0.24825, 0.64264]
# Buyer 0.64364 | Bids: [0.24825, 0.64364]
# Buyer 0.64464 | Bids: [0.24825, 0.64464]
# Buyer 0.64565 | Bids: [0.24825, 0.64565]
# Buyer 0.64665 | Bids: [0.24825, 0.64665]
# Buyer 0.64765 | Bids: [0.24825, 0.64765]
# Buyer 0.64865 | Bids: [0.24825, 0.64865]
# Buyer 0.64965 | Bids: [0.24825, 0.64965]
# Buyer 0.65065 | Bids: [0.24825, 0.65065]
# Buyer 0.65165 | Bids: [0.24825, 0.65165]
# Buyer 0.65265 | Bids: [0.24825, 0.65265]
# Buyer 0.65365 | Bids: [0.24825, 0.65365]
# Buyer 0.65465 | Bids: [0.24825, 0.65465]
# Buyer 0.65566 | Bids: [0.24825, 0.65566]
# Buyer 0.65666 | Bids: [0.24825, 0.65666]
# Buyer 0.65766 | Bids: [0.24825, 0.65766]
# Buyer 0.65866 | Bids: [0.24825, 0.65866]
# Buyer 0.65966 | Bids: [0.24825, 0.65966]
# Buyer 0.66066 | Bids: [0.24825, 0.66066]
# Buyer 0.66166 | Bids: [0.24825, 0.66166]
# Buyer 0.66266 | Bids: [0.24825, 0.66266]
# Buyer 0.66366 | Bids: [0.24825, 0.66366]
# Buyer 0.66466 | Bids: [0.24825, 0.66466]
# Buyer 0.66567 | Bids: [0.24825, 0.66567]
# Buyer 0.66667 | Bids: [0.24825, 0.66667]
# Buyer 0.66767 | Bids: [0.24825, 0.66767]
# Buyer 0.66867 | Bids: [0.24825, 0.66867]
# Buyer 0.66967 | Bids: [0.24825, 0.66967]
# Buyer 0.67067 | Bids: [0.24825, 0.67067]
# Buyer 0.67167 | Bids: [0.24825, 0.67167]
# Buyer 0.67267 | Bids: [0.24825, 0.67267]
# Buyer 0.67367 | Bids: [0.24825, 0.67367]
# Buyer 0.67467 | Bids: [0.24825, 0.67467]
# Buyer 0.67568 | Bids: [0.24825, 0.67568]
# Buyer 0.67668 | Bids: [0.24825, 0.67668]
# Buyer 0.67768 | Bids: [0.24825, 0.67768]
# Buyer 0.67868 | Bids: [0.24825, 0.67868]
# Buyer 0.67968 | Bids: [0.24825, 0.67968]
# Buyer 0.68068 | Bids: [0.24825, 0.68068]
# Buyer 0.68168 | Bids: [0.24825, 0.68168]
# Buyer 0.68268 | Bids: [0.24825, 0.68268]
# Buyer 0.68368 | Bids: [0.24825, 0.68368]
# Buyer 0.68468 | Bids: [0.24825, 0.68468]
# Buyer 0.68569 | Bids: [0.24825, 0.68569]
# Buyer 0.68669 | Bids: [0.24825, 0.68669]
# Buyer 0.68769 | Bids: [0.24825, 0.68769]
# Buyer 0.68869 | Bids: [0.24825, 0.68869]
# Buyer 0.68969 | Bids: [0.24825, 0.68969]
# Buyer 0.69069 | Bids: [0.24825, 0.69069]
# Buyer 0.69169 | Bids: [0.24825, 0.69169]
# Buyer 0.69269 | Bids: [0.24825, 0.69269]
# Buyer 0.69369 | Bids: [0.24825, 0.69369]
# Buyer 0.69469 | Bids: [0.24825, 0.69469]
# Buyer 0.69570 | Bids: [0.24825, 0.69570]
# Buyer 0.69670 | Bids: [0.24825, 0.69670]
# Buyer 0.69770 | Bids: [0.24825, 0.69770]
# Buyer 0.69870 | Bids: [0.24825, 0.69870]
# Buyer 0.69970 | Bids: [0.24825, 0.69970]
# Buyer 0.70070 | Bids: [0.24825, 0.70070]
# Buyer 0.70170 | Bids: [0.24825, 0.70170]
# Buyer 0.70270 | Bids: [0.24825, 0.70270]
# Buyer 0.70370 | Bids: [0.24825, 0.70370]
# Buyer 0.70470 | Bids: [0.24825, 0.70470]
# Buyer 0.70571 | Bids: [0.24825, 0.70571]
# Buyer 0.70671 | Bids: [0.24825, 0.70671]
# Buyer 0.70771 | Bids: [0.24825, 0.70771]
# Buyer 0.70871 | Bids: [0.24825, 0.70871]
# Buyer 0.70971 | Bids: [0.24825, 0.70971]
# Buyer 0.71071 | Bids: [0.24825, 0.71071]
# Buyer 0.71171 | Bids: [0.24825, 0.71171]
# Buyer 0.71271 | Bids: [0.24825, 0.71271]
# Buyer 0.71371 | Bids: [0.24825, 0.71371]
# Buyer 0.71471 | Bids: [0.24825, 0.71471]
# Buyer 0.71572 | Bids: [0.24825, 0.71572]
# Buyer 0.71672 | Bids: [0.24825, 0.71672]
# Buyer 0.71772 | Bids: [0.24825, 0.71772]
# Buyer 0.71872 | Bids: [0.24825, 0.71872]
# Buyer 0.71972 | Bids: [0.24825, 0.71972]
# Buyer 0.72072 | Bids: [0.24825, 0.72072]
# Buyer 0.72172 | Bids: [0.24825, 0.72172]
# Buyer 0.72272 | Bids: [0.24825, 0.72272]
# Buyer 0.72372 | Bids: [0.24825, 0.72372]
# Buyer 0.72472 | Bids: [0.24825, 0.72472]
# Buyer 0.72573 | Bids: [0.24825, 0.72573]
# Buyer 0.72673 | Bids: [0.24825, 0.72673]
# Buyer 0.72773 | Bids: [0.24825, 0.72773]
# Buyer 0.72873 | Bids: [0.24825, 0.72873]
# Buyer 0.72973 | Bids: [0.24825, 0.72973]
# Buyer 0.73073 | Bids: [0.24825, 0.73073]
# Buyer 0.73173 | Bids: [0.24825, 0.73173]
# Buyer 0.73273 | Bids: [0.24825, 0.73273]
# Buyer 0.73373 | Bids: [0.24825, 0.73373]
# Buyer 0.73473 | Bids: [0.24825, 0.73473]
# Buyer 0.73574 | Bids: [0.24825, 0.73574]
# Buyer 0.73674 | Bids: [0.24825, 0.73674]
# Buyer 0.73774 | Bids: [0.24825, 0.73774]
# Buyer 0.73874 | Bids: [0.24825, 0.73874]
# Buyer 0.73974 | Bids: [0.24825, 0.73974]
# Buyer 0.74074 | Bids: [0.24825, 0.74074]
# Buyer 0.74174 | Bids: [0.24825, 0.74174]
# Buyer 0.74274 | Bids: [0.24825, 0.74274]
# Buyer 0.74374 | Bids: [0.24825, 0.74374]
# Buyer 0.74474 | Bids: [0.24825, 0.74474]
# Buyer 0.74575 | Bids: [0.24825, 0.74575]
# Buyer 0.74675 | Bids: [0.24825, 0.74675]
# Buyer 0.74775 | Bids: [0.24825, 0.74775]
# Buyer 0.74875 | Bids: [0.24825, 0.74875]
# Buyer 0.74975 | Bids: [0.24825, 0.74975]
# Buyer 0.75075 | Bids: [0.24825, 0.75075]
# Buyer 0.75175 | Bids: [0.24825, 0.75175]
# Buyer 0.75275 | Bids: [0.24825, 0.75275]
# Buyer 0.75375 | Bids: [0.24825, 0.75375]
# Buyer 0.75475 | Bids: [0.24825, 0.75475]
# Buyer 0.75576 | Bids: [0.24825, 0.75576]
# Buyer 0.75676 | Bids: [0.24825, 0.75676]
# Buyer 0.75776 | Bids: [0.24825, 0.75776]
# Buyer 0.75876 | Bids: [0.24825, 0.75876]
# Buyer 0.75976 | Bids: [0.24825, 0.75976]
# Buyer 0.76076 | Bids: [0.24825, 0.76076]
# Buyer 0.76176 | Bids: [0.24825, 0.76176]
# Buyer 0.76276 | Bids: [0.24825, 0.76276]
# Buyer 0.76376 | Bids: [0.24825, 0.76376]
# Buyer 0.76476 | Bids: [0.24825, 0.76476]
# Buyer 0.76577 | Bids: [0.24825, 0.76577]
# Buyer 0.76677 | Bids: [0.24825, 0.76677]
# Buyer 0.76777 | Bids: [0.24825, 0.76777]
# Buyer 0.76877 | Bids: [0.24825, 0.76877]
# Buyer 0.76977 | Bids: [0.24825, 0.76977]
# Buyer 0.77077 | Bids: [0.24825, 0.77077]
# Buyer 0.77177 | Bids: [0.24825, 0.77177]
# Buyer 0.77277 | Bids: [0.24825, 0.77277]
# Buyer 0.77377 | Bids: [0.24825, 0.77377]
# Buyer 0.77477 | Bids: [0.24825, 0.77477]
# Buyer 0.77578 | Bids: [0.24825, 0.77578]
# Buyer 0.77678 | Bids: [0.24825, 0.77678]
# Buyer 0.77778 | Bids: [0.24825, 0.77778]
# Buyer 0.77878 | Bids: [0.24825, 0.77878]
# Buyer 0.77978 | Bids: [0.24825, 0.77978]
# Buyer 0.78078 | Bids: [0.24825, 0.78078]
# Buyer 0.78178 | Bids: [0.24825, 0.78178]
# Buyer 0.78278 | Bids: [0.24825, 0.78278]
# Buyer 0.78378 | Bids: [0.24825, 0.78378]
# Buyer 0.78478 | Bids: [0.24825, 0.78478]
# Buyer 0.78579 | Bids: [0.24825, 0.78579]
# Buyer 0.78679 | Bids: [0.24825, 0.78679]
# Buyer 0.78779 | Bids: [0.24825, 0.78779]
# Buyer 0.78879 | Bids: [0.24825, 0.78879]
# Buyer 0.78979 | Bids: [0.24825, 0.78979]
# Buyer 0.79079 | Bids: [0.24825, 0.79079]
# Buyer 0.79179 | Bids: [0.24825, 0.79179]
# Buyer 0.79279 | Bids: [0.24825, 0.79279]
# Buyer 0.79379 | Bids: [0.24825, 0.79379]
# Buyer 0.79479 | Bids: [0.24825, 0.79479]
# Buyer 0.79580 | Bids: [0.24825, 0.79580]
# Buyer 0.79680 | Bids: [0.24825, 0.79680]
# Buyer 0.79780 | Bids: [0.24825, 0.79780]
# Buyer 0.79880 | Bids: [0.24825, 0.79880]
# Buyer 0.79980 | Bids: [0.24825, 0.79980]
# Buyer 0.80080 | Bids: [0.24825, 0.80080]
# Buyer 0.80180 | Bids: [0.24825, 0.80180]
# Buyer 0.80280 | Bids: [0.24825, 0.80280]
# Buyer 0.80380 | Bids: [0.24825, 0.80380]
# Buyer 0.80480 | Bids: [0.24825, 0.80480]
# Buyer 0.80581 | Bids: [0.24825, 0.80581]
# Buyer 0.80681 | Bids: [0.24825, 0.80681]
# Buyer 0.80781 | Bids: [0.24825, 0.80781]
# Buyer 0.80881 | Bids: [0.24825, 0.80881]
# Buyer 0.80981 | Bids: [0.24825, 0.80981]
# Buyer 0.81081 | Bids: [0.24825, 0.81081]
# Buyer 0.81181 | Bids: [0.24825, 0.81181]
# Buyer 0.81281 | Bids: [0.24825, 0.81281]
# Buyer 0.81381 | Bids: [0.24825, 0.81381]
# Buyer 0.81481 | Bids: [0.24825, 0.81481]
# Buyer 0.81582 | Bids: [0.24825, 0.81582]
# Buyer 0.81682 | Bids: [0.24825, 0.81682]
# Buyer 0.81782 | Bids: [0.24825, 0.81782]
# Buyer 0.81882 | Bids: [0.24825, 0.81882]
# Buyer 0.81982 | Bids: [0.24825, 0.81982]
# Buyer 0.82082 | Bids: [0.24825, 0.82082]
# Buyer 0.82182 | Bids: [0.24825, 0.82182]
# Buyer 0.82282 | Bids: [0.24825, 0.82282]
# Buyer 0.82382 | Bids: [0.24825, 0.82382]
# Buyer 0.82482 | Bids: [0.24825, 0.82482]
# Buyer 0.82583 | Bids: [0.24825, 0.82583]
# Buyer 0.82683 | Bids: [0.24825, 0.82683]
# Buyer 0.82783 | Bids: [0.24825, 0.82783]
# Buyer 0.82883 | Bids: [0.24825, 0.82883]
# Buyer 0.82983 | Bids: [0.24825, 0.82983]
# Buyer 0.83083 | Bids: [0.24825, 0.83083]
# Buyer 0.83183 | Bids: [0.24825, 0.83183]
# Buyer 0.83283 | Bids: [0.24825, 0.83283]
# Buyer 0.83383 | Bids: [0.24825, 0.83383]
# Buyer 0.83483 | Bids: [0.24825, 0.83483]
# Buyer 0.83584 | Bids: [0.24825, 0.83584]
# Buyer 0.83684 | Bids: [0.24825, 0.83684]
# Buyer 0.83784 | Bids: [0.24825, 0.83784]
# Buyer 0.83884 | Bids: [0.24825, 0.83884]
# Buyer 0.83984 | Bids: [0.24825, 0.83984]
# Buyer 0.84084 | Bids: [0.24825, 0.84084]
# Buyer 0.84184 | Bids: [0.24825, 0.84184]
# Buyer 0.84284 | Bids: [0.24825, 0.84284]
# Buyer 0.84384 | Bids: [0.24825, 0.84384]
# Buyer 0.84484 | Bids: [0.24825, 0.84484]
# Buyer 0.84585 | Bids: [0.24825, 0.84585]
# Buyer 0.84685 | Bids: [0.24825, 0.84685]
# Buyer 0.84785 | Bids: [0.24825, 0.84785]
# Buyer 0.84885 | Bids: [0.24825, 0.84885]
# Buyer 0.84985 | Bids: [0.24825, 0.84985]
# Buyer 0.85085 | Bids: [0.24825, 0.85085]
# Buyer 0.85185 | Bids: [0.24825, 0.85185]
# Buyer 0.85285 | Bids: [0.24825, 0.85285]
# Buyer 0.85385 | Bids: [0.24825, 0.85385]
# Buyer 0.85485 | Bids: [0.24825, 0.85485]
# Buyer 0.85586 | Bids: [0.24825, 0.85586]
# Buyer 0.85686 | Bids: [0.24825, 0.85686]
# Buyer 0.85786 | Bids: [0.24825, 0.85786]
# Buyer 0.85886 | Bids: [0.24825, 0.85886]
# Buyer 0.85986 | Bids: [0.24825, 0.85986]
# Buyer 0.86086 | Bids: [0.24825, 0.86086]
# Buyer 0.86186 | Bids: [0.24825, 0.86186]
# Buyer 0.86286 | Bids: [0.24825, 0.86286]
# Buyer 0.86386 | Bids: [0.24825, 0.86386]
# Buyer 0.86486 | Bids: [0.24825, 0.86486]
# Buyer 0.86587 | Bids: [0.24825, 0.86587]
# Buyer 0.86687 | Bids: [0.24825, 0.86687]
# Buyer 0.86787 | Bids: [0.24825, 0.86787]
# Buyer 0.86887 | Bids: [0.24825, 0.86887]
# Buyer 0.86987 | Bids: [0.24825, 0.86987]
# Buyer 0.87087 | Bids: [0.24825, 0.87087]
# Buyer 0.87187 | Bids: [0.24825, 0.87187]
# Buyer 0.87287 | Bids: [0.24825, 0.87287]
# Buyer 0.87387 | Bids: [0.24825, 0.87387]
# Buyer 0.87487 | Bids: [0.24825, 0.87487]
# Buyer 0.87588 | Bids: [0.24825, 0.87588]
# Buyer 0.87688 | Bids: [0.24825, 0.87688]
# Buyer 0.87788 | Bids: [0.24825, 0.87788]
# Buyer 0.87888 | Bids: [0.24825, 0.87888]
# Buyer 0.87988 | Bids: [0.24825, 0.87988]
# Buyer 0.88088 | Bids: [0.24825, 0.88088]
# Buyer 0.88188 | Bids: [0.24825, 0.88188]
# Buyer 0.88288 | Bids: [0.24825, 0.88288]
# Buyer 0.88388 | Bids: [0.24825, 0.88388]
# Buyer 0.88488 | Bids: [0.24825, 0.88488]
# Buyer 0.88589 | Bids: [0.24825, 0.88589]
# Buyer 0.88689 | Bids: [0.24825, 0.88689]
# Buyer 0.88789 | Bids: [0.24825, 0.88789]
# Buyer 0.88889 | Bids: [0.24825, 0.88889]
# Buyer 0.88989 | Bids: [0.24825, 0.88989]
# Buyer 0.89089 | Bids: [0.24825, 0.89089]
# Buyer 0.89189 | Bids: [0.24825, 0.89189]
# Buyer 0.89289 | Bids: [0.24825, 0.89289]
# Buyer 0.89389 | Bids: [0.24825, 0.89389]
# Buyer 0.89489 | Bids: [0.24825, 0.89489]
# Buyer 0.89590 | Bids: [0.24825, 0.89590]
# Buyer 0.89690 | Bids: [0.24825, 0.89690]
# Buyer 0.89790 | Bids: [0.24825, 0.89790]
# Buyer 0.89890 | Bids: [0.24825, 0.89890]
# Buyer 0.89990 | Bids: [0.24825, 0.89990]
# Buyer 0.90090 | Bids: [0.24825, 0.90090]
# Buyer 0.90190 | Bids: [0.24825, 0.90190]
# Buyer 0.90290 | Bids: [0.24825, 0.90290]
# Buyer 0.90390 | Bids: [0.24825, 0.90390]
# Buyer 0.90490 | Bids: [0.24825, 0.90490]
# Buyer 0.90591 | Bids: [0.24825, 0.90591]
# Buyer 0.90691 | Bids: [0.24825, 0.90691]
# Buyer 0.90791 | Bids: [0.24825, 0.90791]
# Buyer 0.90891 | Bids: [0.24825, 0.90891]
# Buyer 0.90991 | Bids: [0.24825, 0.90991]
# Buyer 0.91091 | Bids: [0.24825, 0.91091]
# Buyer 0.91191 | Bids: [0.24825, 0.91191]
# Buyer 0.91291 | Bids: [0.24825, 0.91291]
# Buyer 0.91391 | Bids: [0.24825, 0.91391]
# Buyer 0.91491 | Bids: [0.24825, 0.91491]
# Buyer 0.91592 | Bids: [0.24825, 0.91592]
# Buyer 0.91692 | Bids: [0.24825, 0.91692]
# Buyer 0.91792 | Bids: [0.24825, 0.91792]
# Buyer 0.91892 | Bids: [0.24825, 0.91892]
# Buyer 0.91992 | Bids: [0.24825, 0.91992]
# Buyer 0.92092 | Bids: [0.24825, 0.92092]
# Buyer 0.92192 | Bids: [0.24825, 0.92192]
# Buyer 0.92292 | Bids: [0.24825, 0.92292]
# Buyer 0.92392 | Bids: [0.24825, 0.92392]
# Buyer 0.92492 | Bids: [0.24825, 0.92492]
# Buyer 0.92593 | Bids: [0.24825, 0.92593]
# Buyer 0.92693 | Bids: [0.24825, 0.92693]
# Buyer 0.92793 | Bids: [0.24825, 0.92793]
# Buyer 0.92893 | Bids: [0.24825, 0.92893]
# Buyer 0.92993 | Bids: [0.24825, 0.92993]
# Buyer 0.93093 | Bids: [0.24825, 0.93093]
# Buyer 0.93193 | Bids: [0.24825, 0.93193]
# Buyer 0.93293 | Bids: [0.24825, 0.93293]
# Buyer 0.93393 | Bids: [0.24825, 0.93393]
# Buyer 0.93493 | Bids: [0.24825, 0.93493]
# Buyer 0.93594 | Bids: [0.24825, 0.93594]
# Buyer 0.93694 | Bids: [0.24825, 0.93694]
# Buyer 0.93794 | Bids: [0.24825, 0.93794]
# Buyer 0.93894 | Bids: [0.24825, 0.93894]
# Buyer 0.93994 | Bids: [0.24825, 0.93994]
# Buyer 0.94094 | Bids: [0.24825, 0.94094]
# Buyer 0.94194 | Bids: [0.24825, 0.94194]
# Buyer 0.94294 | Bids: [0.24825, 0.94294]
# Buyer 0.94394 | Bids: [0.24825, 0.94394]
# Buyer 0.94494 | Bids: [0.24825, 0.94494]
# Buyer 0.94595 | Bids: [0.24825, 0.94595]
# Buyer 0.94695 | Bids: [0.24825, 0.94695]
# Buyer 0.94795 | Bids: [0.24825, 0.94795]
# Buyer 0.94895 | Bids: [0.24825, 0.94895]
# Buyer 0.94995 | Bids: [0.24825, 0.94995]
# Buyer 0.95095 | Bids: [0.24825, 0.95095]
# Buyer 0.95195 | Bids: [0.24825, 0.95195]
# Buyer 0.95295 | Bids: [0.24825, 0.95295]
# Buyer 0.95395 | Bids: [0.24825, 0.95395]
# Buyer 0.95495 | Bids: [0.24825, 0.95495]
# Buyer 0.95596 | Bids: [0.24825, 0.95596]
# Buyer 0.95696 | Bids: [0.24825, 0.95696]
# Buyer 0.95796 | Bids: [0.24825, 0.95796]
# Buyer 0.95896 | Bids: [0.24825, 0.95896]
# Buyer 0.95996 | Bids: [0.24825, 0.95996]
# Buyer 0.96096 | Bids: [0.24825, 0.96096]
# Buyer 0.96196 | Bids: [0.24825, 0.96196]
# Buyer 0.96296 | Bids: [0.24825, 0.96296]
# Buyer 0.96396 | Bids: [0.24825, 0.96396]
# Buyer 0.96496 | Bids: [0.24825, 0.96496]
# Buyer 0.96597 | Bids: [0.24825, 0.96597]
# Buyer 0.96697 | Bids: [0.24825, 0.96697]
# Buyer 0.96797 | Bids: [0.24825, 0.96797]
# Buyer 0.96897 | Bids: [0.24825, 0.96897]
# Buyer 0.96997 | Bids: [0.24825, 0.96997]
# Buyer 0.97097 | Bids: [0.24825, 0.97097]
# Buyer 0.97197 | Bids: [0.24825, 0.97197]
# Buyer 0.97297 | Bids: [0.24825, 0.97297]
# Buyer 0.97397 | Bids: [0.24825, 0.97397]
# Buyer 0.97497 | Bids: [0.24825, 0.97497]
# Buyer 0.97598 | Bids: [0.24825, 0.97598]
# Buyer 0.97698 | Bids: [0.24825, 0.97698]
# Buyer 0.97798 | Bids: [0.24825, 0.97798]
# Buyer 0.97898 | Bids: [0.24825, 0.97898]
# Buyer 0.97998 | Bids: [0.24825, 0.97998]
# Buyer 0.98098 | Bids: [0.24825, 0.98098]
# Buyer 0.98198 | Bids: [0.24825, 0.98198]
# Buyer 0.98298 | Bids: [0.24825, 0.98298]
# Buyer 0.98398 | Bids: [0.24825, 0.98398]
# Buyer 0.98498 | Bids: [0.24825, 0.98498]
# Buyer 0.98599 | Bids: [0.24825, 0.98599]
# Buyer 0.98699 | Bids: [0.24825, 0.98699]
# Buyer 0.98799 | Bids: [0.24825, 0.98799]
# Buyer 0.98899 | Bids: [0.24825, 0.98899]
# Buyer 0.98999 | Bids: [0.24825, 0.98999]
# Buyer 0.99099 | Bids: [0.24825, 0.99099]
# Buyer 0.99199 | Bids: [0.24825, 0.99199]
# Buyer 0.99299 | Bids: [0.24825, 0.99299]
# Buyer 0.99399 | Bids: [0.24825, 0.99399]
# Buyer 0.99499 | Bids: [0.24825, 0.99499]
# Buyer 0.99600 | Bids: [0.24825, 0.99600]
# Buyer 0.99700 | Bids: [0.24825, 0.99700]
# Buyer 0.99800 | Bids: [0.24825, 0.99800]
# Buyer 0.99900 | Bids: [0.24825, 0.99900]
# Buyer 1.00000 | Bids: [0.24825, 1.00000]
#
# =======================================================
# ================ SELLER OFFERING RANGES ===============
# =======================================================
# Seller 0.00000 | Offers: [0.00000, 0.75175]
# Seller 0.00100 | Offers: [0.00100, 0.75175]
# Seller 0.00200 | Offers: [0.00200, 0.75175]
# Seller 0.00300 | Offers: [0.00300, 0.75175]
# Seller 0.00400 | Offers: [0.00400, 0.75175]
# Seller 0.00501 | Offers: [0.00501, 0.75175]
# Seller 0.00601 | Offers: [0.00601, 0.75175]
# Seller 0.00701 | Offers: [0.00701, 0.75175]
# Seller 0.00801 | Offers: [0.00801, 0.75175]
# Seller 0.00901 | Offers: [0.00901, 0.75175]
# Seller 0.01001 | Offers: [0.01001, 0.75175]
# Seller 0.01101 | Offers: [0.01101, 0.75175]
# Seller 0.01201 | Offers: [0.01201, 0.75175]
# Seller 0.01301 | Offers: [0.01301, 0.75175]
# Seller 0.01401 | Offers: [0.01401, 0.75175]
# Seller 0.01502 | Offers: [0.01502, 0.75175]
# Seller 0.01602 | Offers: [0.01602, 0.75175]
# Seller 0.01702 | Offers: [0.01702, 0.75175]
# Seller 0.01802 | Offers: [0.01802, 0.75175]
# Seller 0.01902 | Offers: [0.01902, 0.75175]
# Seller 0.02002 | Offers: [0.02002, 0.75175]
# Seller 0.02102 | Offers: [0.02102, 0.75175]
# Seller 0.02202 | Offers: [0.02202, 0.75175]
# Seller 0.02302 | Offers: [0.02302, 0.75175]
# Seller 0.02402 | Offers: [0.02402, 0.75175]
# Seller 0.02503 | Offers: [0.02503, 0.75175]
# Seller 0.02603 | Offers: [0.02603, 0.75175]
# Seller 0.02703 | Offers: [0.02703, 0.75175]
# Seller 0.02803 | Offers: [0.02803, 0.75175]
# Seller 0.02903 | Offers: [0.02903, 0.75175]
# Seller 0.03003 | Offers: [0.03003, 0.75175]
# Seller 0.03103 | Offers: [0.03103, 0.75175]
# Seller 0.03203 | Offers: [0.03203, 0.75175]
# Seller 0.03303 | Offers: [0.03303, 0.75175]
# Seller 0.03403 | Offers: [0.03403, 0.75175]
# Seller 0.03504 | Offers: [0.03504, 0.75175]
# Seller 0.03604 | Offers: [0.03604, 0.75175]
# Seller 0.03704 | Offers: [0.03704, 0.75175]
# Seller 0.03804 | Offers: [0.03804, 0.75175]
# Seller 0.03904 | Offers: [0.03904, 0.75175]
# Seller 0.04004 | Offers: [0.04004, 0.75175]
# Seller 0.04104 | Offers: [0.04104, 0.75175]
# Seller 0.04204 | Offers: [0.04204, 0.75175]
# Seller 0.04304 | Offers: [0.04304, 0.75175]
# Seller 0.04404 | Offers: [0.04404, 0.75175]
# Seller 0.04505 | Offers: [0.04505, 0.75175]
# Seller 0.04605 | Offers: [0.04605, 0.75175]
# Seller 0.04705 | Offers: [0.04705, 0.75175]
# Seller 0.04805 | Offers: [0.04805, 0.75175]
# Seller 0.04905 | Offers: [0.04905, 0.75175]
# Seller 0.05005 | Offers: [0.05005, 0.75175]
# Seller 0.05105 | Offers: [0.05105, 0.75175]
# Seller 0.05205 | Offers: [0.05205, 0.75175]
# Seller 0.05305 | Offers: [0.05305, 0.75175]
# Seller 0.05405 | Offers: [0.05405, 0.75175]
# Seller 0.05506 | Offers: [0.05506, 0.75175]
# Seller 0.05606 | Offers: [0.05606, 0.75175]
# Seller 0.05706 | Offers: [0.05706, 0.75175]
# Seller 0.05806 | Offers: [0.05806, 0.75175]
# Seller 0.05906 | Offers: [0.05906, 0.75175]
# Seller 0.06006 | Offers: [0.06006, 0.75175]
# Seller 0.06106 | Offers: [0.06106, 0.75175]
# Seller 0.06206 | Offers: [0.06206, 0.75175]
# Seller 0.06306 | Offers: [0.06306, 0.75175]
# Seller 0.06406 | Offers: [0.06406, 0.75175]
# Seller 0.06507 | Offers: [0.06507, 0.75175]
# Seller 0.06607 | Offers: [0.06607, 0.75175]
# Seller 0.06707 | Offers: [0.06707, 0.75175]
# Seller 0.06807 | Offers: [0.06807, 0.75175]
# Seller 0.06907 | Offers: [0.06907, 0.75175]
# ...
# Seller 0.71071 | Offers: [0.71071, 0.75175]
# Seller 0.71171 | Offers: [0.71171, 0.75175]
# Seller 0.71271 | Offers: [0.71271, 0.75175]
# Seller 0.71371 | Offers: [0.71371, 0.75175]
# Seller 0.71471 | Offers: [0.71471, 0.75175]
# Seller 0.71572 | Offers: [0.71572, 0.75175]
# Seller 0.71672 | Offers: [0.71672, 0.75175]
# Seller 0.71772 | Offers: [0.71772, 0.75175]
# Seller 0.71872 | Offers: [0.71872, 0.75175]
# Seller 0.71972 | Offers: [0.71972, 0.75175]
# Seller 0.72072 | Offers: [0.72072, 0.75175]
# Seller 0.72172 | Offers: [0.72172, 0.75175]
# Seller 0.72272 | Offers: [0.72272, 0.75175]
# Seller 0.72372 | Offers: [0.72372, 0.75175]
# Seller 0.72472 | Offers: [0.72472, 0.75175]
# Seller 0.72573 | Offers: [0.72573, 0.75175]
# Seller 0.72673 | Offers: [0.72673, 0.75175]
# Seller 0.72773 | Offers: [0.72773, 0.75175]
# Seller 0.72873 | Offers: [0.72873, 0.75175]
# Seller 0.72973 | Offers: [0.72973, 0.75175]
# Seller 0.73073 | Offers: [0.73073, 0.75175]
# Seller 0.73173 | Offers: [0.73173, 0.75175]
# Seller 0.73273 | Offers: [0.73273, 0.75175]
# Seller 0.73373 | Offers: [0.73373, 0.75175]
# Seller 0.73473 | Offers: [0.73473, 0.75175]
# Seller 0.73574 | Offers: [0.73574, 0.75175]
# Seller 0.73674 | Offers: [0.73674, 0.75175]
# Seller 0.73774 | Offers: [0.73774, 0.75175]
# Seller 0.73874 | Offers: [0.73874, 0.75175]
# Seller 0.73974 | Offers: [0.73974, 0.75175]
# Seller 0.74074 | Offers: [0.74074, 0.75175]
# Seller 0.74174 | Offers: [0.74174, 0.75175]
# Seller 0.74274 | Offers: [0.74274, 0.75175]
# Seller 0.74374 | Offers: [0.74374, 0.75175]
# Seller 0.74474 | Offers: [0.74474, 0.75175]
# Seller 0.74575 | Offers: [0.74575, 0.75175]
# Seller 0.74675 | Offers: [0.74675, 0.75175]
# Seller 0.74775 | Offers: [0.74775, 0.75175]
# Seller 0.74875 | Offers: [0.74875, 0.75175]
# Seller 0.74975 | Offers: [0.74975, 0.75175]
# Seller 0.75075 | Offers: [0.75075, 0.75175]
# Seller 0.75175 | [0.75175] (Only Possible Offer)
# Seller 0.75275 | not in serious offers (above threshold)
# Seller 0.75375 | not in serious offers (above threshold)
# Seller 0.75475 | not in serious offers (above threshold)
# Seller 0.75576 | not in serious offers (above threshold)
# Seller 0.75676 | not in serious offers (above threshold)
# Seller 0.75776 | not in serious offers (above threshold)
# Seller 0.75876 | not in serious offers (above threshold)
# Seller 0.75976 | not in serious offers (above threshold)
# Seller 0.76076 | not in serious offers (above threshold)
# Seller 0.76176 | not in serious offers (above threshold)
# Seller 0.76276 | not in serious offers (above threshold)
# Seller 0.76376 | not in serious offers (above threshold)
# Seller 0.76476 | not in serious offers (above threshold)
# Seller 0.76577 | not in serious offers (above threshold)
# Seller 0.76677 | not in serious offers (above threshold)
# Seller 0.76777 | not in serious offers (above threshold)
# Seller 0.76877 | not in serious offers (above threshold)
# Seller 0.76977 | not in serious offers (above threshold)
# Seller 0.77077 | not in serious offers (above threshold)
# Seller 0.77177 | not in serious offers (above threshold)
# Seller 0.77277 | not in serious offers (above threshold)
# Seller 0.77377 | not in serious offers (above threshold)
# Seller 0.77477 | not in serious offers (above threshold)
# Seller 0.77578 | not in serious offers (above threshold)
# Seller 0.77678 | not in serious offers (above threshold)
# Seller 0.77778 | not in serious offers (above threshold)
# Seller 0.77878 | not in serious offers (above threshold)
# Seller 0.77978 | not in serious offers (above threshold)
# Seller 0.78078 | not in serious offers (above threshold)
# Seller 0.78178 | not in serious offers (above threshold)
# Seller 0.78278 | not in serious offers (above threshold)
# Seller 0.78378 | not in serious offers (above threshold)
# Seller 0.78478 | not in serious offers (above threshold)
# Seller 0.78579 | not in serious offers (above threshold)
# Seller 0.78679 | not in serious offers (above threshold)
# Seller 0.78779 | not in serious offers (above threshold)
# Seller 0.78879 | not in serious offers (above threshold)
# Seller 0.78979 | not in serious offers (above threshold)
# Seller 0.79079 | not in serious offers (above threshold)
# Seller 0.79179 | not in serious offers (above threshold)
# Seller 0.79279 | not in serious offers (above threshold)
# Seller 0.79379 | not in serious offers (above threshold)
# Seller 0.79479 | not in serious offers (above threshold)
# Seller 0.79580 | not in serious offers (above threshold)
# Seller 0.79680 | not in serious offers (above threshold)
# Seller 0.79780 | not in serious offers (above threshold)
# Seller 0.79880 | not in serious offers (above threshold)
# Seller 0.79980 | not in serious offers (above threshold)
# Seller 0.80080 | not in serious offers (above threshold)
# Seller 0.80180 | not in serious offers (above threshold)
# Seller 0.80280 | not in serious offers (above threshold)
# Seller 0.80380 | not in serious offers (above threshold)
# Seller 0.80480 | not in serious offers (above threshold)
# Seller 0.80581 | not in serious offers (above threshold)
# Seller 0.80681 | not in serious offers (above threshold)
# Seller 0.80781 | not in serious offers (above threshold)
# Seller 0.80881 | not in serious offers (above threshold)
# Seller 0.80981 | not in serious offers (above threshold)
# Seller 0.81081 | not in serious offers (above threshold)
# Seller 0.81181 | not in serious offers (above threshold)
# Seller 0.81281 | not in serious offers (above threshold)
# Seller 0.81381 | not in serious offers (above threshold)
# Seller 0.81481 | not in serious offers (above threshold)
# Seller 0.81582 | not in serious offers (above threshold)
# Seller 0.81682 | not in serious offers (above threshold)
# Seller 0.81782 | not in serious offers (above threshold)
# Seller 0.81882 | not in serious offers (above threshold)
# Seller 0.81982 | not in serious offers (above threshold)
# Seller 0.82082 | not in serious offers (above threshold)
# Seller 0.82182 | not in serious offers (above threshold)
# Seller 0.82282 | not in serious offers (above threshold)
# Seller 0.82382 | not in serious offers (above threshold)
# Seller 0.82482 | not in serious offers (above threshold)
# Seller 0.82583 | not in serious offers (above threshold)
# Seller 0.82683 | not in serious offers (above threshold)
# Seller 0.82783 | not in serious offers (above threshold)
# Seller 0.82883 | not in serious offers (above threshold)
# Seller 0.82983 | not in serious offers (above threshold)
# Seller 0.83083 | not in serious offers (above threshold)
# Seller 0.83183 | not in serious offers (above threshold)
# Seller 0.83283 | not in serious offers (above threshold)
# Seller 0.83383 | not in serious offers (above threshold)
# Seller 0.83483 | not in serious offers (above threshold)
# Seller 0.83584 | not in serious offers (above threshold)
# Seller 0.83684 | not in serious offers (above threshold)
# Seller 0.83784 | not in serious offers (above threshold)
# Seller 0.83884 | not in serious offers (above threshold)
# Seller 0.83984 | not in serious offers (above threshold)
# Seller 0.84084 | not in serious offers (above threshold)
# Seller 0.84184 | not in serious offers (above threshold)
# Seller 0.84284 | not in serious offers (above threshold)
# Seller 0.84384 | not in serious offers (above threshold)
# Seller 0.84484 | not in serious offers (above threshold)
# Seller 0.84585 | not in serious offers (above threshold)
# Seller 0.84685 | not in serious offers (above threshold)
# Seller 0.84785 | not in serious offers (above threshold)
# Seller 0.84885 | not in serious offers (above threshold)
# Seller 0.84985 | not in serious offers (above threshold)
# Seller 0.85085 | not in serious offers (above threshold)
# Seller 0.85185 | not in serious offers (above threshold)
# Seller 0.85285 | not in serious offers (above threshold)
# Seller 0.85385 | not in serious offers (above threshold)
# Seller 0.85485 | not in serious offers (above threshold)
# Seller 0.85586 | not in serious offers (above threshold)
# Seller 0.85686 | not in serious offers (above threshold)
# Seller 0.85786 | not in serious offers (above threshold)
# Seller 0.85886 | not in serious offers (above threshold)
# Seller 0.85986 | not in serious offers (above threshold)
# Seller 0.86086 | not in serious offers (above threshold)
# Seller 0.86186 | not in serious offers (above threshold)
# Seller 0.86286 | not in serious offers (above threshold)
# Seller 0.86386 | not in serious offers (above threshold)
# Seller 0.86486 | not in serious offers (above threshold)
# Seller 0.86587 | not in serious offers (above threshold)
# Seller 0.86687 | not in serious offers (above threshold)
# Seller 0.86787 | not in serious offers (above threshold)
# Seller 0.86887 | not in serious offers (above threshold)
# Seller 0.86987 | not in serious offers (above threshold)
# Seller 0.87087 | not in serious offers (above threshold)
# Seller 0.87187 | not in serious offers (above threshold)
# Seller 0.87287 | not in serious offers (above threshold)
# Seller 0.87387 | not in serious offers (above threshold)
# Seller 0.87487 | not in serious offers (above threshold)
# Seller 0.87588 | not in serious offers (above threshold)
# Seller 0.87688 | not in serious offers (above threshold)
# Seller 0.87788 | not in serious offers (above threshold)
# Seller 0.87888 | not in serious offers (above threshold)
# Seller 0.87988 | not in serious offers (above threshold)
# Seller 0.88088 | not in serious offers (above threshold)
# Seller 0.88188 | not in serious offers (above threshold)
# Seller 0.88288 | not in serious offers (above threshold)
# Seller 0.88388 | not in serious offers (above threshold)
# Seller 0.88488 | not in serious offers (above threshold)
# Seller 0.88589 | not in serious offers (above threshold)
# Seller 0.88689 | not in serious offers (above threshold)
# Seller 0.88789 | not in serious offers (above threshold)
# Seller 0.88889 | not in serious offers (above threshold)
# Seller 0.88989 | not in serious offers (above threshold)
# Seller 0.89089 | not in serious offers (above threshold)
# Seller 0.89189 | not in serious offers (above threshold)
# Seller 0.89289 | not in serious offers (above threshold)
# Seller 0.89389 | not in serious offers (above threshold)
# Seller 0.89489 | not in serious offers (above threshold)
# Seller 0.89590 | not in serious offers (above threshold)
# Seller 0.89690 | not in serious offers (above threshold)
# Seller 0.89790 | not in serious offers (above threshold)
# Seller 0.89890 | not in serious offers (above threshold)
# Seller 0.89990 | not in serious offers (above threshold)
# Seller 0.90090 | not in serious offers (above threshold)
# Seller 0.90190 | not in serious offers (above threshold)
# Seller 0.90290 | not in serious offers (above threshold)
# Seller 0.90390 | not in serious offers (above threshold)
# Seller 0.90490 | not in serious offers (above threshold)
# Seller 0.90591 | not in serious offers (above threshold)
# Seller 0.90691 | not in serious offers (above threshold)
# Seller 0.90791 | not in serious offers (above threshold)
# Seller 0.90891 | not in serious offers (above threshold)
# Seller 0.90991 | not in serious offers (above threshold)
# Seller 0.91091 | not in serious offers (above threshold)
# Seller 0.91191 | not in serious offers (above threshold)
# Seller 0.91291 | not in serious offers (above threshold)
# Seller 0.91391 | not in serious offers (above threshold)
# Seller 0.91491 | not in serious offers (above threshold)
# Seller 0.91592 | not in serious offers (above threshold)
# Seller 0.91692 | not in serious offers (above threshold)
# Seller 0.91792 | not in serious offers (above threshold)
# Seller 0.91892 | not in serious offers (above threshold)
# Seller 0.91992 | not in serious offers (above threshold)
# Seller 0.92092 | not in serious offers (above threshold)
# Seller 0.92192 | not in serious offers (above threshold)
# Seller 0.92292 | not in serious offers (above threshold)
# Seller 0.92392 | not in serious offers (above threshold)
# Seller 0.92492 | not in serious offers (above threshold)
# Seller 0.92593 | not in serious offers (above threshold)
# Seller 0.92693 | not in serious offers (above threshold)
# Seller 0.92793 | not in serious offers (above threshold)
# Seller 0.92893 | not in serious offers (above threshold)
# Seller 0.92993 | not in serious offers (above threshold)
# Seller 0.93093 | not in serious offers (above threshold)
# Seller 0.93193 | not in serious offers (above threshold)
# Seller 0.93293 | not in serious offers (above threshold)
# Seller 0.93393 | not in serious offers (above threshold)
# Seller 0.93493 | not in serious offers (above threshold)
# Seller 0.93594 | not in serious offers (above threshold)
# Seller 0.93694 | not in serious offers (above threshold)
# Seller 0.93794 | not in serious offers (above threshold)
# Seller 0.93894 | not in serious offers (above threshold)
# Seller 0.93994 | not in serious offers (above threshold)
# Seller 0.94094 | not in serious offers (above threshold)
# Seller 0.94194 | not in serious offers (above threshold)
# Seller 0.94294 | not in serious offers (above threshold)
# Seller 0.94394 | not in serious offers (above threshold)
# Seller 0.94494 | not in serious offers (above threshold)
# Seller 0.94595 | not in serious offers (above threshold)
# Seller 0.94695 | not in serious offers (above threshold)
# Seller 0.94795 | not in serious offers (above threshold)
# Seller 0.94895 | not in serious offers (above threshold)
# Seller 0.94995 | not in serious offers (above threshold)
# Seller 0.95095 | not in serious offers (above threshold)
# Seller 0.95195 | not in serious offers (above threshold)
# Seller 0.95295 | not in serious offers (above threshold)
# Seller 0.95395 | not in serious offers (above threshold)
# Seller 0.95495 | not in serious offers (above threshold)
# Seller 0.95596 | not in serious offers (above threshold)
# Seller 0.95696 | not in serious offers (above threshold)
# Seller 0.95796 | not in serious offers (above threshold)
# Seller 0.95896 | not in serious offers (above threshold)
# Seller 0.95996 | not in serious offers (above threshold)
# Seller 0.96096 | not in serious offers (above threshold)
# Seller 0.96196 | not in serious offers (above threshold)
# Seller 0.96296 | not in serious offers (above threshold)
# Seller 0.96396 | not in serious offers (above threshold)
# Seller 0.96496 | not in serious offers (above threshold)
# Seller 0.96597 | not in serious offers (above threshold)
# Seller 0.96697 | not in serious offers (above threshold)
# Seller 0.96797 | not in serious offers (above threshold)
# Seller 0.96897 | not in serious offers (above threshold)
# Seller 0.96997 | not in serious offers (above threshold)
# Seller 0.97097 | not in serious offers (above threshold)
# Seller 0.97197 | not in serious offers (above threshold)
# Seller 0.97297 | not in serious offers (above threshold)
# Seller 0.97397 | not in serious offers (above threshold)
# Seller 0.97497 | not in serious offers (above threshold)
# Seller 0.97598 | not in serious offers (above threshold)
# Seller 0.97698 | not in serious offers (above threshold)
# Seller 0.97798 | not in serious offers (above threshold)
# Seller 0.97898 | not in serious offers (above threshold)
# Seller 0.97998 | not in serious offers (above threshold)
# Seller 0.98098 | not in serious offers (above threshold)
# Seller 0.98198 | not in serious offers (above threshold)
# Seller 0.98298 | not in serious offers (above threshold)
# Seller 0.98398 | not in serious offers (above threshold)
# Seller 0.98498 | not in serious offers (above threshold)
# Seller 0.98599 | not in serious offers (above threshold)
# Seller 0.98699 | not in serious offers (above threshold)
# Seller 0.98799 | not in serious offers (above threshold)
# Seller 0.98899 | not in serious offers (above threshold)
# Seller 0.98999 | not in serious offers (above threshold)
# Seller 0.99099 | not in serious offers (above threshold)
# Seller 0.99199 | not in serious offers (above threshold)
# Seller 0.99299 | not in serious offers (above threshold)
# Seller 0.99399 | not in serious offers (above threshold)
# Seller 0.99499 | not in serious offers (above threshold)
# Seller 0.99600 | not in serious offers (above threshold)
# Seller 0.99700 | not in serious offers (above threshold)
# Seller 0.99800 | not in serious offers (above threshold)
# Seller 0.99900 | not in serious offers (above threshold)
# Seller 1.00000 | not in serious offers (above threshold)

# %%
# ------------------------------------------------------
# Cell 3: Enhanced Implementation with Silverman's Rule 
# (Section 4.2: Adaptation of Discrete vb and vs)
# ------------------------------------------------------

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# -------------------------------------------
# Necessary Syntax for Proper Visualizations
# -------------------------------------------

def print_array(label, arr, decimals=5):
    """Print full array without truncation"""
    print(f"\n{label} ({len(arr)} items):")
    print("[" + ", ".join([f"{x:.{decimals}f}" for x in arr]) + "]")

# -----------------------------------------------------------------
# Algorithmic Formalization of Defintion 5 (Empirical PDF and CDF)
# -----------------------------------------------------------------

def compute_distribution(values):
    """Calculate discrete PDF/CDF for values"""
    unique_vals, counts = np.unique(values, return_counts=True)
    
    # ------------------------------------
    # Empirical Probability Mass Function
    # ------------------------------------
    
    pdf = counts / counts.sum()
    
    # -------------------------------------------
    # Empirical Cumulative Distribution Function
    # -------------------------------------------
    
    cdf = np.cumsum(pdf)
    return unique_vals, pdf, cdf

# -----------------------------------------------------------------------------
# Algorithmic Formalization of Method 3 (Smoothed PDF and CDF via Bounded KDE)
# -----------------------------------------------------------------------------

def compute_smoothed_distribution(values, bandwidth, data_range=(0,1)):
    """Calculate KDE-smoothed PDF/CDF with proper range handling"""
    if len(values) < 2:
        return None, None, None
    kde = gaussian_kde(values, bw_method=bandwidth)
    x_smooth = np.linspace(data_range[0], data_range[1], 200)
    pdf_smooth = kde.evaluate(x_smooth)
    
    # ----------------------------------------------------------------
    # Normalize PDF to Integrate to 1 Over the Specified Range [l, u]
    # ----------------------------------------------------------------
    
    pdf_smooth /= np.trapz(pdf_smooth, x_smooth)
    cdf_smooth = np.cumsum(pdf_smooth)
    cdf_smooth /= cdf_smooth[-1]  # Ensure CDF ends at 1
    return x_smooth, pdf_smooth, cdf_smooth

# --------------------------------------------------------------------------------
# Algorithmic Formalization of Method 1 (Adaptive Bandwidth for Bounded Support)
# --------------------------------------------------------------------------------

def adaptive_bandwidth(data, data_range=(0,1)):
    """Silverman's rule adapted for bounded support"""
    n = len(data)
    range_width = data_range[1] - data_range[0]
    
    if n < 2:                     # ----------------------------
        return 0.1 * range_width  # Base minimum on range width
                                  # ----------------------------
    
    # -------------------------------------------------------------
    # Silverman's Normal Reference Rule with Reflection Adjustment
    # -------------------------------------------------------------
    
    sigma = np.std(data, ddof=1)
    reflection_factor = 1 + (sigma**2)/(range_width**2)
    bw = 1.06 * sigma * (n ** (-0.2)) * (reflection_factor ** 0.2)
    
    # ---------------------------------------------
    # Bandwidth Constraints to Avoid Oversmoothing
    # ---------------------------------------------
    
    return np.clip(bw, 0.05 * range_width, 0.5 * range_width)

# -----------------------------------------------------------
# Algorithmic Formalization of Method 2 (Boundary Jittering)
# -----------------------------------------------------------

def preprocess_valuations(values, epsilon=0.005):
    """Uniform-optimized jittering"""
    processed = []
    for v in values:
        if np.isclose(v, 0) or np.isclose(v, 1):
            processed.append(v)
        else:                                              # --------------------------
            jitter = np.random.uniform(-epsilon, epsilon)  # epsilon ~ (-delta, delta)
            processed.append(np.clip(v + jitter, 0, 1))    # --------------------------
    return np.array(processed)

# ----------------------------------------------------
# Applying the Processing Procedures for Definition 6
# ----------------------------------------------------

v_lower = serious_values_interval[0]
c_upper = serious_values_interval[1]

vb_serious_orig = [v for v in vb if v_lower <= v <= c_upper]  
vs_serious_orig = [v for v in vs if v_lower <= v <= c_upper] 
serious_values_orig = np.intersect1d(vb_serious_orig, vs_serious_orig)

# ----------------------------------------
# Print "Processed Value Sets" (Figure 3)
# ----------------------------------------

print("\n=== PROCESSED VALUE SETS ===")
vb_processed = preprocess_valuations(vb)
print_array("Processed Buyer Values (vb_processed)", vb_processed)

vs_processed = preprocess_valuations(vs)
print_array("Processed Seller Values (vs_processed)", vs_processed)

vb_serious_processed = preprocess_valuations(vb_serious_orig)
print_array("Processed Serious Buyer Values (vb_serious_processed)", vb_serious_processed)

vs_serious_processed = preprocess_valuations(vs_serious_orig)
print_array("Processed Serious Seller Values (vs_serious_processed)", vs_serious_processed)

serious_processed = preprocess_valuations(serious_values_orig)
print_array("Processed Combined Serious Values (serious_processed)", serious_processed)

# -----------------------
# Bandwidth Calculations
# -----------------------

bw_vb = adaptive_bandwidth(vb_processed, (0,1))
bw_vs = adaptive_bandwidth(vs_processed, (0,1))
bw_vb_serious = adaptive_bandwidth(vb_serious_processed, (v_lower, c_upper))
bw_vs_serious = adaptive_bandwidth(vs_serious_processed, (v_lower, c_upper))
bw_serious = adaptive_bandwidth(serious_processed, (v_lower, c_upper))

# ------------------------------------------------------
# Enhanced Visualization of the Processed Distributions
# ------------------------------------------------------

def plot_combined_distributions(original, processed, bw, title, interval):
    """Enhanced visualization with Silverman bandwidth"""
    plt.figure(figsize=(18, 6))
    plt.suptitle(f"{title}\nSilverman BW: {bw:.4f}, Interval: {interval}", y=1.05)
    
    # --------------------
    # PDF Plot (Figure 4)
    # --------------------
    
    plt.subplot(1, 2, 1)
    if len(original) > 0:
        unique_orig, pdf_orig, _ = compute_distribution(original)
        plt.stem(unique_orig, pdf_orig, linefmt='#2c7bb6', markerfmt='o',
                 basefmt=' ', label='Discrete PDF')
    
    if processed is not None and len(processed) > 1:
        x_smooth, pdf_smooth, _ = compute_smoothed_distribution(processed, bw, interval)
        plt.plot(x_smooth, pdf_smooth, color='#d7191c', lw=2, label='KDE PDF')
    
    plt.xlim(interval)
    plt.grid(True)
    plt.legend()
    
    # --------------------
    # CDF Plot (Figure 4)
    # --------------------
    
    plt.subplot(1, 2, 2)
    if len(original) > 0:
        _, _, cdf_orig = compute_distribution(original)
        plt.step(np.insert(unique_orig, 0, interval[0]), np.insert(cdf_orig, 0, 0),
                 where='post', color='#2c7bb6', label='Discrete CDF')
    
    if processed is not None and len(processed) > 1:
        _, _, cdf_smooth = compute_smoothed_distribution(processed, bw, interval)
        plt.plot(x_smooth, cdf_smooth, color='#d7191c', lw=2, label='KDE CDF')
    
    plt.xlim(interval)
    plt.grid(True)
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# ------------------------
# Generate Visualizations
# ------------------------

try:
    print("\n=== VISUALIZATIONS ===")
    print("\n=== FULL DISTRIBUTIONS ===")
    plot_combined_distributions(vb, vb_processed, bw_vb, "Buyers", (0, 1))
    plot_combined_distributions(vs, vs_processed, bw_vs, "Sellers", (0, 1))

    print("\n=== SERIOUS VALUE ANALYSIS ===")
    plot_combined_distributions(vb_serious_orig, vb_serious_processed, bw_vb_serious, 
                              "Serious Buyers", (v_lower, 1.0))
    plot_combined_distributions(vs_serious_orig, vs_serious_processed, bw_vs_serious, 
                              "Serious Sellers", (0.0, c_upper))
    plot_combined_distributions(serious_values_orig, serious_processed, bw_serious,
                              "Combined Serious", (v_lower, c_upper))

# -------------------------------------------------
# Store KDE results for Serious Buyers and Sellers
# -------------------------------------------------

    x_smooth_vb, pdf_smooth_vb, _ = compute_smoothed_distribution(
        vb_serious_processed, bw_vb_serious, (v_lower, 1.0))
    x_smooth_vs, pdf_smooth_vs, _ = compute_smoothed_distribution(
        vs_serious_processed, bw_vs_serious, (0.0, c_upper))
    
    global_kde_results = {
        'serious_buyer_x': x_smooth_vb,
        'serious_buyer_pdf': pdf_smooth_vb,
        'serious_seller_x': x_smooth_vs,
        'serious_seller_pdf': pdf_smooth_vs,
        'buyer_domain': (v_lower, 1.0), 
        'seller_domain': (0.0, c_upper),
        'serious_domain': (v_lower, c_upper),
        'v_lower': v_lower,
        'c_upper': c_upper,
        'vb_serious_processed': vb_serious_processed,
        'vs_serious_processed': vs_serious_processed,
        'serious_processed': serious_processed
    }
        
except Exception as e:
    print(f"Error storing KDE results: {str(e)}")

# -----------------------------------------------------
# Model Validation, Print "Core Validation"
# -----------------------------------------------------

def validate_uniform_processing(original, processed, interval):
    print(f"\nValidation for [{interval[0]:.5f}, {interval[1]:.5f}]:")
    print(f"Original mean: {np.mean(original):.5f}  Processed mean: {np.mean(processed):.5f}")
    print(f"Max deviation: {np.max(np.abs(processed - original)):.5f}")
    print(f"Within interval: {100 * np.mean((processed >= interval[0]) & (processed <= interval[1])):.5f}%")

    
print("\n=== CORE VALIDATION ===")
validate_uniform_processing(vb_serious_orig, vb_serious_processed, (v_lower, 1.0))
validate_uniform_processing(vs_serious_orig, vs_serious_processed, (0.0, c_upper))
# %%
# -----------------------------------------------------------------------------
# Root-finding Algorithm and Formalization of the Original Model from RWS 1994
# (Section 4.3: Robust Equilibrium Implementation)
# -----------------------------------------------------------------------------

print("NOTE: THESE ERROR MESSAGES ARE THEORETICALLY SOUND, DUE TO MISREPRESENTATION NO STABLE EQUILIBRIUM SHOULD BE POSSIBLE")
from scipy.optimize import root_scalar
from scipy.integrate import quad
from scipy.interpolate import interp1d
import numpy as np
import warnings
from scipy.integrate import IntegrationWarning
warnings.simplefilter("ignore", IntegrationWarning)

# ----------------------------------------------------------------------
# Algorithmic Formalization of k-DA Baseline Strategies in Definition 7
# ----------------------------------------------------------------------

def theoretical_buyer_bid(v):
    """From RWS Equation (3.1)"""
    return v_lower + (v - v_lower) * (1 - k)

def theoretical_seller_offer(c):
    """From RWS Equation (3.2)"""
    return c_upper - (c_upper - c) * (1 - k)

# ----------------------------------------------------------------------------------
# Algorithmic Formalization of the Numerical Probability Integration in Defintion 8
# ----------------------------------------------------------------------------------

def log_K_nm(lam, m, n):
    """Log probability ≥n sellers bid ≤λ using numerical integration"""
    try:
        # ----------------------------------------------
        # Get valid integration bounds from KDE results
        # ----------------------------------------------
        
        min_c = global_kde_results['seller_domain'][0]
        max_c = global_kde_results['seller_domain'][1]
        lower = max(0.0, min_c)
        upper = min(lam, max_c)
        integ = quad(lambda x: seller_pdf_func(x), lower, upper)[0]
        return n * np.log(max(integ, 1e-100))
    except:
        return -np.inf

def log_L_nm(lam, m, n):
    """Log probability ≥m-1 buyers bid ≥λ using numerical integration"""
    try:
        # ----------------------------------------------
        # Get valid integration bounds from KDE results
        # ----------------------------------------------
        
        min_v = global_kde_results['buyer_domain'][0]
        max_v = global_kde_results['buyer_domain'][1]
        lower = max(lam, min_v)
        upper = min(1.0, max_v)
        integ = quad(lambda x: buyer_pdf_func(x), lower, upper)[0]
        return (m-1) * np.log(max(integ, 1e-100))
    except:
        return -np.inf

def log_M_nm(lam, m, n):
    """Combined numerical integration with domain awareness"""
    try:
        # -------------------------
        # Buyer survival component
        # -------------------------
        
        b_min = global_kde_results['buyer_domain'][0]
        b_max = global_kde_results['buyer_domain'][1]
        buyer_survival = quad(lambda x: buyer_pdf_func(x), 
                              max(lam, b_min), 
                              min(1.0, b_max))[0]
        
        # ---------------------
        # Seller CDF component
        # ---------------------
        
        s_min = global_kde_results['seller_domain'][0]
        s_max = global_kde_results['seller_domain'][1]
        seller_cdf = quad(lambda x: seller_pdf_func(x), 
                          max(0.0, s_min), 
                          min(lam, s_max))[0]
        
        return (m-1)*np.log(max(buyer_survival, 1e-100)) + n*np.log(max(seller_cdf, 1e-100))
    except:
        return -np.inf

# -----------------------------------------------------
# Parameters for Complex-Step Derivative Approximation
# -----------------------------------------------------

                        # ----------------
SAFE_DERIVATIVE = 1e-8  # delta = 10^(-8) 
                        # ----------------

                        # --------------------------------------
DERIV_EPS = 1e-20       # epsilon = 10^(-20): Complex step size
                        # --------------------------------------

# ---------------------------------------------------------------------------------------
# Algorithmic Formalization of the Complex-Step Derivative Approximation in Definition 9
# ---------------------------------------------------------------------------------------

def complex_step_derivative(func, x):
    deriv = np.imag(func(x + DERIV_EPS*1j)) / DERIV_EPS
    return np.clip(deriv, SAFE_DERIVATIVE, None) if deriv > 0 else np.clip(deriv, None, -SAFE_DERIVATIVE)

# ---------------------------------------------
# Stabilized PDF Extension (KDE Interpolation)
# ---------------------------------------------

buyer_pdf_func = interp1d(
    global_kde_results['serious_buyer_x'],     # -------------------------------------
    global_kde_results['serious_buyer_pdf'],   # Linear Interpolation of Buyer Values
    bounds_error=False,                        # -------------------------------------
    
                                  # ------------------------------------
    fill_value=(1e-100, 1e-100)   # Definiton of varepsilon = 10^(-100)
)                                 # ------------------------------------

seller_pdf_func = interp1d(
    global_kde_results['serious_seller_x'],    # --------------------------------------
    global_kde_results['serious_seller_pdf'],  # Linear Interpolation of Seller Values
    bounds_error=False,                        # --------------------------------------
    fill_value=(1e-100, 1e-100)
)

# ------------------------------------------------------
# Stabilized First-Order-Condition Solver from Method 4
# ------------------------------------------------------

                 # ----------------------------------------------------
LOG_CLAMP = 700  # Log-clamping Parameter from Remark 2, and Elsewhere
                 # ----------------------------------------------------
    
# --------------------------------------------
# Buyer-Equilibrium Computation from Method 5
# --------------------------------------------

def buyer_foc(lam, v, m, n):
    if lam < v_lower or lam > c_upper:
        return np.inf if lam < v_lower else -np.inf

    try:
        f = max(seller_pdf_func(lam), 1e-100)
        g = max(buyer_pdf_func(v), 1e-100)
        
        dB = complex_step_derivative(theoretical_buyer_bid, v)
        dS = complex_step_derivative(theoretical_seller_offer, lam)
        
        # -------------------------------------------------------------------------
        # Log-space calculations with overflow protection from Equations (15)-(17)
        # -------------------------------------------------------------------------
        
        log_K = np.clip(log_K_nm(lam, m, n), -LOG_CLAMP, LOG_CLAMP)
        log_L = np.clip(log_L_nm(lam, m, n), -LOG_CLAMP, LOG_CLAMP)
        log_M = np.clip(log_M_nm(lam, m, n), -LOG_CLAMP, LOG_CLAMP)
        
        K = np.exp(log_K) if abs(log_K) < LOG_CLAMP else 0.0
        L = np.exp(log_L) if abs(log_L) < LOG_CLAMP else 0.0
        M = np.exp(log_M) if abs(log_M) < LOG_CLAMP else 0.0
        
        # -------------------------------------------
        # Core FOC Calculation [Exact Equation (15)]
        # -------------------------------------------
        
        term1 = (v - k) * (n * K * f / max(abs(dS), SAFE_DERIVATIVE) + 
                           (m-1) * L * g / max(abs(dB), SAFE_DERIVATIVE))
        term2 = k * M
        return term1 - term2
    except Exception as e:
        print(f"FOC error at v={v:.4f}, λ={lam:.4f}: {str(e)}")
        return np.inf

# ------------------------------------------------------------------
# 4. Buyer Equilibrium Calculation with Safe Brackets from Method 5
# ------------------------------------------------------------------

def calculate_buyer_equilibrium():
    equilibrium = {}
    m = len(vb_serious_processed)
    n = len(vs_serious_processed)
    
    bid_min = v_lower
    bid_max = c_upper
    
    buyer_warning_printed = False
    
    for v in vb_serious_processed:
        try:
            theory_bid = theoretical_buyer_bid(v)
            safe_bracket = (
                max(bid_min, theory_bid - 0.1, v_lower),
                min(bid_max, theory_bid + 0.1, v)
            )
            if safe_bracket[0] >= safe_bracket[1]:
                safe_bracket = (bid_min, min(bid_max, v))
            
            # ---------------------------------------------
            # Use of the Robust 1-D Solver: Brent's Method
            # ---------------------------------------------
            
            sol = root_scalar(
                buyer_foc,
                args=(v, m, n),
                bracket=safe_bracket,
                method='brentq',
                xtol=1e-6,
                rtol=1e-5
            )
            
            equilibrium[v] = np.clip(sol.root, bid_min, bid_max)
        except Exception as e:
            if not buyer_warning_printed:
                print(f"Using theoretical bid for v={v:.4f}: {str(e)}")
                buyer_warning_printed = True
            equilibrium[v] = np.clip(theory_bid, bid_min, bid_max)
    
    return equilibrium

buyer_eq = calculate_buyer_equilibrium()

# ------------------------------------------------------------------------------------
# Algorithmic Formalization of the Extension to "all valuations" from (b) in Method 5
# ------------------------------------------------------------------------------------

def extend_buyer_equilibrium(full_valuations, eq_dict, v_lower, c_upper):

    extended_eq = {}
    
    # ------------------------------------------------------------------------------------
    # We assume eq_dict[v_lower] and eq_dict[c_upper] exist if they’re in the serious set
    # If not, we can clamp or handle them gracefully.
    # ------------------------------------------------------------------------------------
    
    B_v_lower = eq_dict.get(v_lower, theoretical_buyer_bid(v_lower))
    B_c_upper = eq_dict.get(c_upper, theoretical_buyer_bid(c_upper))
    
    for v in full_valuations:
        if v < v_lower:
            
            # -------------------------------------------
            # Project downward from v_lower with slope 1
            # -------------------------------------------
            
            extended_eq[v] = B_v_lower - (v_lower - v)
        elif v > c_upper:
            
            # -----------------------------------------
            # Project upward from c_upper with slope 1
            # -----------------------------------------
            
            extended_eq[v] = B_c_upper + (v - c_upper)
        else:
            if v in eq_dict:
                extended_eq[v] = eq_dict[v]
            else:
                extended_eq[v] = theoretical_buyer_bid(v)
    return extended_eq

# ------------------------------------------------------------------------------
# Algorithmic Formalization of the Seller-Equilibrium Computation from Method 6
# ------------------------------------------------------------------------------

def calculate_seller_equilibrium():
    equilibrium = {}
    warned_bracket_issue = False
    bids = np.array(list(buyer_eq.values()))
    
    # -----------------------------------------------
    # Algorithmic Formalization of (a) from Method 6
    # -----------------------------------------------
    
    serious_sellers = serious_processed
    offers = [
        c_upper - (c_upper - v_lower) * (1 - k) * (c / c_upper) 
        for c in serious_sellers
    ]
    
    for c in serious_sellers:
        try:
                                 # ----------------------------------------------
            def seller_foc(a):   # Seller First-Order Condition, (b) in Method 6
                                 # ----------------------------------------------
                
                numerator = quad(lambda x: buyer_pdf_func(x), a, c_upper)[0]
                denominator = max(buyer_pdf_func(a), 1e-100)
                return (a - c) - (numerator / denominator)
            
            bracket_low = max(c, v_lower)
            bracket_high = min(c_upper, c + 0.1*(c_upper - v_lower))
            sol = root_scalar(
                seller_foc,
                bracket=[bracket_low, bracket_high],
                
                                   # --------------------------------------------
                method='brentq',   # Root Finding Algorithm using Brent's Method
                                   # --------------------------------------------
                
                xtol=1e-6
            )
            
            equilibrium[c] = np.clip(sol.root, c, c_upper)
        except Exception as e:
            if not warned_bracket_issue:
                print(f"Warning: Seller root-finding failed for c={c:.4f}. Using theoretical offer. Error: {str(e)}")
                warned_bracket_issue = True
            equilibrium[c] = np.clip(theoretical_seller_offer(c), c, c_upper)
    
    return equilibrium
seller_eq = calculate_seller_equilibrium()

# ----------------------------------------------
# Agorithmic Formalization of (b) from Method 6
# ----------------------------------------------

def extend_seller_equilibrium(full_valuations, eq_dict, v_lower, c_upper):
    
    extended_eq = {}
    
    S_v_lower = eq_dict.get(v_lower, theoretical_seller_offer(v_lower))
    S_c_upper = eq_dict.get(c_upper, theoretical_seller_offer(c_upper))
    
    for c in full_valuations:
        if c < v_lower:
            
            # ----------------------
            # slope=1 below v_lower
            # ----------------------
            
            extended_eq[c] = S_v_lower - (v_lower - c)
        elif c > c_upper:
            
            # ----------------------
            # slope=1 above c_upper
            # ----------------------
            
            extended_eq[c] = S_c_upper + (c - c_upper)
        else:
            if c in eq_dict:
                extended_eq[c] = eq_dict[c]
            else:
                extended_eq[c] = theoretical_seller_offer(c)
    return extended_eq

# --------------------------------------
# Algorithmic Formalization of Figure 5
# --------------------------------------

extended_buyer_eq = extend_buyer_equilibrium(vb, buyer_eq, v_lower, c_upper)
extended_seller_eq = extend_seller_equilibrium(vs, seller_eq, v_lower, c_upper)

def print_equilibrium_table():
    # Header
    print("\n" + "="*65)
    print(" STRATEGIC EQUILIBRIUM (RWS 1994 COMPATIBLE) ".center(65, '='))
    print("="*65)
    print(f"Trading Interval: [{v_lower:.4f}, {c_upper:.4f}]")
    print(f"Number of Possible Buyer Values: {len(vb_serious_processed)}, Number of Possible Seller Values: {len(vs_serious_processed)}")
    print(f"Mechanims Parameter k: {k:.2f}\n")
    
    # ---------------------------------------
    # Print "Buyer Bids (B(vb))" (Figure 5)
    # ---------------------------------------
    
    print("-"*65)
    print(" BUYER BIDS (B(vb)) ".center(65, '-'))
    print("{:<12} {:<18} {:<18} {:<10}".format("Valuation", "Computed", "Theoretical", "Δ"))
    for v in sorted(extended_buyer_eq):
        comp = extended_buyer_eq[v]
        theory = theoretical_buyer_bid(v)
        diff = comp - theory
        print(f"{v:.5f}    {comp:.5f} ({comp/theory:.2%})  {theory:.5f}       {diff:+.4f}")
    
    # ------------------------------------------
    # Print "Seller Offers (S(vs))" (Figure 5)
    # ------------------------------------------
    
    print("\n" + "-"*65)
    print(" SELLER OFFERS (S(vs)) ".center(65, '-'))
    print("{:<12} {:<18} {:<18} {:<10}".format("Cost", "Computed", "Theoretical", "Δ"))
    for c in sorted(extended_seller_eq):
        comp = extended_seller_eq[c]
        theory = theoretical_seller_offer(c)
        diff = comp - theory
        print(f"{c:.5f}    {comp:.5f} ({comp/theory:.2%})  {theory:.5f}       {diff:+.4f}")

print_equilibrium_table()
# Out:
# NOTE: THESE ERROR MESSAGES ARE THEORETICALLY SOUND, DUE TO MISREPRESENTATION NO STABLE EQUILIBRIUM SHOULD BE POSSIBLE
# Using theoretical bid for v=0.2502: f(a) and f(b) must have different signs
# Warning: Seller root-finding failed for c=0.2473. Using theoretical offer. Error: f(a) and f(b) must have different signs
import numpy as np

# -------------------------------------------------
# Print "Verifying Buyer Conditions" from Figure 6
# -------------------------------------------------

print("\n" + "="*55)
print(" VERIFYING BUYER CONDITIONS ".center(55, '='))
print("="*55 + "\n")

inequality_violated = False

                             # --------------------------------
numerical_tolerance = 1e-6   # Real Parameter, gamma = 10^(-6) 
                             # --------------------------------

                   # -------------------------------
SAFE_EPS = 1e-12   # Rescaled varepsilon = 10^(-12)
                   # -------------------------------

# ---------------------------------------------
# Get Computed Equilibrium Parameters, m and n
# ---------------------------------------------

m = len(buyer_eq)
n = len(seller_eq)

# ---------------------------------------------
# Print "Market Parameters" Section (Figure 6)
# ---------------------------------------------

print(f"Market Parameters:")
print(f" Number of Possible Buyer Values: {m}, Number of Possible Seller Values: {n}")
print(f"- k value: {k:.2f}")
print(f"- Trading interval: [{v_lower:.4f}, {c_upper:.4f}]\n")

print("{:<12} {:<12} {:<12} {:<12} {:<14}".format(
    "Valuation", "Bid", "LHS", "Threshold", "Status"))
print("-"*65)

# -------------------------------------------------------------------------------
# Algorithmic Formalization of Method 7 (Stabilized Buyer Inequality Verification)
# -------------------------------------------------------------------------------

for v, lam in buyer_eq.items():
    try:
        
        # --------------------------------------------
        # Stabilized Derivative Calculation, Part (c)
        # --------------------------------------------
        
        dB = complex_step_derivative(theoretical_buyer_bid, v)
        dB = max(abs(dB), SAFE_EPS) * np.sign(dB)
        
        log_L = log_L_nm(lam, m, n)
        log_M = log_M_nm(lam, m, n)
        
        L = np.exp(log_L) if not np.isinf(log_L) else 0.0
        M = np.exp(log_M) if not np.isinf(log_M) else 0.0
        
        g_val = max(buyer_pdf_func(v), SAFE_EPS)
        
        # ---------------------------------------------------------
        # Algorithmic Formalization of Equation (21) from Method 7
        # ---------------------------------------------------------
        
        term1 = (v - lam) * (m-1) * L * (g_val / dB) if abs(dB) > SAFE_EPS else 0
        term2 = k * M
        lhs = term1 - term2
    
        if np.isinf(lhs):
            lhs = np.sign(lhs) * 1e20 
            
        status = "VIOLATED" if lhs > numerical_tolerance else "OK"
        color_code = "\033[91m" if lhs > numerical_tolerance else "\033[92m"
        
        print("{:<10.5f} | {:<10.5f} | {:<10.2e} | {:<10.2e} | {}{:<12}\033[0m".format(
            v, lam, lhs, numerical_tolerance, color_code, status))
        
        if lhs > numerical_tolerance:
            inequality_violated = True
            
    except Exception as e:
        print(f"Error verifying v={v:.5f}: {str(e)}")
        inequality_violated = True

print("\n" + "="*65)
if inequality_violated:
    print("\033[91mWARNING: Potential violations detected\033[0m")
    print("- Possible causes:")
    print("  1. Numerical approximations in density estimation")
    print("  2. Boundary effects near trading interval edges")
    print("  3. Discontinuities in strategic bidding functions")
else:
    print("\033[92mSUCCESS: Inequality holds within tolerance\033[0m")
print("="*65 + "\n")

#----------------------------------------------------------------------------------------
# Algorithmic Formalization of Method 8 (Stabilized Seller-Inequality Verification)
#----------------------------------------------------------------------------------------

print("\n" + "="*55)                                     # ----------------
print(" VERIFYING SELLER CONDITIONS ".center(55, '='))   # RHS of Figure 7
print("="*55 + "\n")                                     # ----------------

seller_inequality_violated = False
numerical_tolerance = 1e-6
SAFE_EPS = 1e-12

# -------------------------------------------
# Same Real Parameters as Buyer Verification
# -------------------------------------------

m = len(buyer_eq)
n = len(seller_eq)

print(f"Market Parameters:")
print(f"- Number of Buyer Values: {m}, Number of Seller Values: {n}")
print(f"- k value: {k:.2f}")
print(f"- Trading interval: [{v_lower:.4f}, {c_upper:.4f}]\n")

print("{:<12} {:<12} {:<12} {:<12} {:<14}".format(
    "Valuation", "Offer", "LHS", "Threshold", "Status"))
print("-"*65)

for c, sigma in seller_eq.items():
    try:
        
        # ---------------------------------------
        # Seller-specific derivative calculation
        # ---------------------------------------
        
        dS = complex_step_derivative(theoretical_seller_offer, c)
        dS = max(abs(dS), SAFE_EPS) * np.sign(dS)
        
        # ------------------------------------------
        # Seller probability terms (swap m/n roles)
        # ------------------------------------------
        
        log_K = log_K_nm(sigma, n, m)  
        log_N = log_M_nm(sigma, n, m)  
        
        K = np.exp(log_K) if not np.isinf(log_K) else 0.0
        N = np.exp(log_N) if not np.isinf(log_N) else 0.0
        
        # --------------------------------------
        # Seller Density, Floored at varepsilon
        # --------------------------------------
        
        f_val = max(seller_pdf_func(c), SAFE_EPS)
        
        # -------------------------------
        # Equation (23) from Method 8
        # -------------------------------
        
        term1 = (sigma - c) * (n-1) * K * (f_val / dS) if abs(dS) > SAFE_EPS else 0
        term2 = k * N
        lhs = term1 - term2
        
        if np.isinf(lhs):
            lhs = np.sign(lhs) * 1e20
            
        status = "VIOLATED" if lhs > numerical_tolerance else "OK"
        color_code = "\033[91m" if lhs > numerical_tolerance else "\033[92m"
        
        print("{:<10.5f} | {:<10.5f} | {:<10.2e} | {:<10.2e} | {}{:<12}\033[0m".format(
            c, sigma, lhs, numerical_tolerance, color_code, status))
        
        if lhs > numerical_tolerance:
            seller_inequality_violated = True
            
    except Exception as e:
        print(f"Error verifying c={c:.5f}: {str(e)}")
        seller_inequality_violated = True

print("\n" + "="*65)
if seller_inequality_violated:
    print("\033[91mWARNING: Seller inequality violations detected\033[0m")
    print("- Potential causes:")
    print("  1. Boundary effects in seller offer strategies")
    print("  2. Discontinuities in seller virtual valuations")
    print("  3. Numerical instability in high-density regions")
else:
    print("\033[92mSUCCESS: Seller conditions hold within tolerance\033[0m")
print("="*65 + "\n")
# Out:
# =======================================================
# ============== VERIFYING BUYER CONDITIONS =============
# =======================================================
#
# Market Parameters:
#  Number of Possible Buyer Values: 504, Number of Possible Seller Values: 504
# - k value: 0.50
# - Trading interval: [0.2482, 0.7518]
#
# Valuation    Bid          LHS          Threshold    Status
# -----------------------------------------------------------------
# 0.24477    | 0.24825    | -3.51e-12  | 1.00e-06   | OK
# 0.24744    | 0.24825    | -8.14e-13  | 1.00e-06   | OK
# 0.25024    | 0.24924    | 6.82e-01   | 1.00e-06   | VIOLATED
# 0.25389    | 0.25107    | 8.88e-01   | 1.00e-06   | VIOLATED
# 0.24895    | 0.24860    | 2.93e-01   | 1.00e-06   | VIOLATED
# 0.25636    | 0.25231    | 6.93e-01   | 1.00e-06   | VIOLATED
# 0.25068    | 0.24946    | 7.61e-01   | 1.00e-06   | VIOLATED
# 0.26014    | 0.25420    | 3.23e-01   | 1.00e-06   | VIOLATED
# 0.25669    | 0.25247    | 6.56e-01   | 1.00e-06   | VIOLATED
# 0.26192    | 0.25508    | 2.11e-01   | 1.00e-06   | VIOLATED
# 0.25929    | 0.25377    | 2.80e-01   | 1.00e-06   | VIOLATED
# 0.25958    | 0.25391    | 3.71e-01   | 1.00e-06   | VIOLATED
# 0.26488    | 0.25656    | 8.28e-02   | 1.00e-06   | VIOLATED
# 0.26027    | 0.25426    | 3.13e-01   | 1.00e-06   | VIOLATED
# 0.26096    | 0.25460    | 2.62e-01   | 1.00e-06   | VIOLATED
# 0.26347    | 0.25586    | 1.29e-01   | 1.00e-06   | VIOLATED
# 0.26843    | 0.25834    | 2.34e-02   | 1.00e-06   | VIOLATED
# 0.26805    | 0.25815    | 2.69e-02   | 1.00e-06   | VIOLATED
# 0.26498    | 0.25661    | 7.95e-02   | 1.00e-06   | VIOLATED
# 0.26879    | 0.25852    | 1.84e-02   | 1.00e-06   | VIOLATED
# 0.26485    | 0.25655    | 8.35e-02   | 1.00e-06   | VIOLATED
# 0.27020    | 0.25922    | 1.17e-02   | 1.00e-06   | VIOLATED
# 0.27164    | 0.25994    | 6.64e-03   | 1.00e-06   | VIOLATED
# 0.27355    | 0.26090    | 2.53e-03   | 1.00e-06   | VIOLATED
# 0.27636    | 0.26231    | 7.65e-04   | 1.00e-06   | VIOLATED
# 0.27453    | 0.26139    | 1.58e-03   | 1.00e-06   | VIOLATED
# 0.27826    | 0.26326    | 3.43e-04   | 1.00e-06   | VIOLATED
# 0.27216    | 0.26020    | 5.11e-03   | 1.00e-06   | VIOLATED
# 0.27338    | 0.26082    | 2.72e-03   | 1.00e-06   | VIOLATED
# 0.27871    | 0.26348    | 2.74e-04   | 1.00e-06   | VIOLATED
# 0.27402    | 0.26113    | 2.05e-03   | 1.00e-06   | VIOLATED
# 0.27943    | 0.26384    | 1.69e-04   | 1.00e-06   | VIOLATED
# 0.27537    | 0.26181    | 1.10e-03   | 1.00e-06   | VIOLATED
# 0.27832    | 0.26328    | 3.34e-04   | 1.00e-06   | VIOLATED
# 0.27785    | 0.26305    | 4.17e-04   | 1.00e-06   | VIOLATED
# 0.28227    | 0.26526    | 3.98e-05   | 1.00e-06   | VIOLATED
# 0.28211    | 0.26518    | 4.26e-05   | 1.00e-06   | VIOLATED
# 0.28644    | 0.26735    | 4.22e-06   | 1.00e-06   | VIOLATED
# 0.28958    | 0.26892    | 7.43e-07   | 1.00e-06   | OK
# 0.28413    | 0.26619    | 1.46e-05   | 1.00e-06   | VIOLATED
# 0.28875    | 0.26850    | 1.17e-06   | 1.00e-06   | VIOLATED
# 0.28744    | 0.26785    | 2.72e-06   | 1.00e-06   | VIOLATED
# 0.28874    | 0.26849    | 1.17e-06   | 1.00e-06   | VIOLATED
# 0.42013    | 0.33419    | 7.65e-38   | 1.00e-06   | OK
# 0.42364    | 0.33594    | 8.34e-39   | 1.00e-06   | OK
# 0.41781    | 0.33303    | 3.07e-37   | 1.00e-06   | OK
# 0.42028    | 0.33426    | 6.95e-38   | 1.00e-06   | OK
# 0.42552    | 0.33688    | 2.43e-39   | 1.00e-06   | OK
# 0.42470    | 0.33648    | 4.16e-39   | 1.00e-06   | OK
# 0.42705    | 0.33765    | 8.71e-40   | 1.00e-06   | OK
# 0.42267    | 0.33546    | 1.56e-38   | 1.00e-06   | OK
# 0.42442    | 0.33633    | 5.02e-39   | 1.00e-06   | OK
# 0.43021    | 0.33923    | 1.00e-40   | 1.00e-06   | OK
# 0.43284    | 0.34054    | 1.67e-41   | 1.00e-06   | OK
# 0.43050    | 0.33938    | 8.24e-41   | 1.00e-06   | OK
# 0.42941    | 0.33883    | 1.73e-40   | 1.00e-06   | OK
# 0.43423    | 0.34124    | 6.72e-42   | 1.00e-06   | OK
# 0.43791    | 0.34308    | 5.89e-43   | 1.00e-06   | OK
# 0.43595    | 0.34210    | 2.14e-42   | 1.00e-06   | OK
# 0.43409    | 0.34117    | 7.37e-42   | 1.00e-06   | OK
# 0.44068    | 0.34447    | 9.74e-44   | 1.00e-06   | OK
# 0.43861    | 0.34343    | 3.75e-43   | 1.00e-06   | OK
# 0.44244    | 0.34534    | 3.11e-44   | 1.00e-06   | OK
# 0.43767    | 0.34296    | 6.90e-43   | 1.00e-06   | OK
# 0.43890    | 0.34358    | 3.06e-43   | 1.00e-06   | OK
# 0.44403    | 0.34614    | 1.11e-44   | 1.00e-06   | OK
# 0.44554    | 0.34690    | 4.19e-45   | 1.00e-06   | OK
# 0.44301    | 0.34563    | 2.14e-44   | 1.00e-06   | OK
# 0.44522    | 0.34673    | 5.18e-45   | 1.00e-06   | OK
# 0.44791    | 0.34808    | 9.08e-46   | 1.00e-06   | OK
# 0.44647    | 0.34736    | 2.29e-45   | 1.00e-06   | OK
# 0.44588    | 0.34706    | 3.37e-45   | 1.00e-06   | OK
# 0.44436    | 0.34630    | 9.08e-45   | 1.00e-06   | OK
# 0.44739    | 0.34782    | 1.27e-45   | 1.00e-06   | OK
# 0.45093    | 0.34959    | 1.28e-46   | 1.00e-06   | OK
# 0.45362    | 0.35094    | 2.29e-47   | 1.00e-06   | OK
# 0.44820    | 0.34822    | 7.56e-46   | 1.00e-06   | OK
# 0.45663    | 0.35244    | 3.34e-48   | 1.00e-06   | OK
# 0.45001    | 0.34913    | 2.33e-46   | 1.00e-06   | OK
# 0.45614    | 0.35219    | 4.54e-48   | 1.00e-06   | OK
# 0.45927    | 0.35376    | 6.23e-49   | 1.00e-06   | OK
# 0.45636    | 0.35230    | 3.95e-48   | 1.00e-06   | OK
# 0.45728    | 0.35277    | 2.21e-48   | 1.00e-06   | OK
# 0.45464    | 0.35145    | 1.19e-47   | 1.00e-06   | OK
# 0.46432    | 0.35629    | 2.58e-50   | 1.00e-06   | OK
# 0.46587    | 0.35706    | 9.50e-51   | 1.00e-06   | OK
# 0.72125    | 0.48475    | 3.40e-135  | 1.00e-06   | OK
# 0.71416    | 0.48120    | 2.21e-132  | 1.00e-06   | OK
# 0.72456    | 0.48640    | 1.40e-136  | 1.00e-06   | OK
# 0.72387    | 0.48606    | 2.78e-136  | 1.00e-06   | OK
# 0.72442    | 0.48633    | 1.62e-136  | 1.00e-06   | OK
# 0.72521    | 0.48673    | 7.40e-137  | 1.00e-06   | OK
# 0.72079    | 0.48452    | 5.25e-135  | 1.00e-06   | OK
# 0.72051    | 0.48438    | 6.84e-135  | 1.00e-06   | OK
# 0.72139    | 0.48482    | 2.99e-135  | 1.00e-06   | OK
# 0.73071    | 0.48948    | 2.94e-139  | 1.00e-06   | OK
# 0.72741    | 0.48783    | 8.28e-138  | 1.00e-06   | OK
# 0.72580    | 0.48703    | 4.10e-137  | 1.00e-06   | OK
# 0.72515    | 0.48670    | 7.84e-137  | 1.00e-06   | OK
# 0.72904    | 0.48864    | 1.60e-138  | 1.00e-06   | OK
# 0.73122    | 0.48973    | 1.73e-139  | 1.00e-06   | OK
# 0.72972    | 0.48898    | 7.99e-139  | 1.00e-06   | OK
# 0.73822    | 0.49323    | 1.45e-142  | 1.00e-06   | OK
# 0.73619    | 0.49222    | 1.12e-141  | 1.00e-06   | OK
# 0.73586    | 0.49205    | 1.57e-141  | 1.00e-06   | OK
# 0.73419    | 0.49122    | 8.42e-141  | 1.00e-06   | OK
# 0.73938    | 0.49381    | 4.58e-143  | 1.00e-06   | OK
# 0.74222    | 0.49523    | 2.63e-144  | 1.00e-06   | OK
# 0.74447    | 0.49636    | 2.70e-145  | 1.00e-06   | OK
# 0.73603    | 0.49214    | 1.31e-141  | 1.00e-06   | OK
# 0.74136    | 0.49481    | 6.22e-144  | 1.00e-06   | OK
# 0.74473    | 0.49649    | 2.09e-145  | 1.00e-06   | OK
# 0.74267    | 0.49546    | 1.68e-144  | 1.00e-06   | OK
# 0.74123    | 0.49474    | 7.19e-144  | 1.00e-06   | OK
# 0.74307    | 0.49566    | 1.13e-144  | 1.00e-06   | OK
# 0.74376    | 0.49601    | 5.55e-145  | 1.00e-06   | OK
# 0.75222    | 0.50023    | 9.33e-149  | 1.00e-06   | OK
# 0.74729    | 0.49777    | 1.56e-146  | 1.00e-06   | OK
# 0.75011    | 0.49918    | 8.52e-148  | 1.00e-06   | OK
# 0.75428    | 0.50126    | 1.04e-149  | 1.00e-06   | OK
# 0.75176    | 0.50000    | 1.54e-148  | 1.00e-06   | OK
#
# =================================================================
# WARNING: Potential violations detected
# - Possible causes:
#   1. Numerical approximations in density estimation
#   2. Boundary effects near trading interval edges
#   3. Discontinuities in strategic bidding functions
# =================================================================
#
#
# =======================================================
# ============= VERIFYING SELLER CONDITIONS =============
# =======================================================
#
# Market Parameters:
# - Number of Buyer Values: 504, Number of Seller Values: 504
# - k value: 0.50
# - Trading interval: [0.2482, 0.7518]
#
# Valuation    Offer        LHS          Threshold    Status
# -----------------------------------------------------------------
# 0.24734    | 0.49954    | 8.25e-149  | 1.00e-06   | OK
# 0.38202    | 0.56688    | 2.95e-97   | 1.00e-06   | OK
# 0.37698    | 0.56437    | 4.75e-99   | 1.00e-06   | OK
# 0.38299    | 0.56737    | 6.47e-97   | 1.00e-06   | OK
# 0.37567    | 0.56371    | 1.61e-99   | 1.00e-06   | OK
# 0.37987    | 0.56581    | 5.04e-98   | 1.00e-06   | OK
# 0.38293    | 0.56734    | 6.17e-97   | 1.00e-06   | OK
# 0.38782    | 0.56979    | 3.24e-95   | 1.00e-06   | OK
# 0.38229    | 0.56702    | 3.66e-97   | 1.00e-06   | OK
# 0.38396    | 0.56785    | 1.43e-96   | 1.00e-06   | OK
# 0.38979    | 0.57077    | 1.58e-94   | 1.00e-06   | OK
# 0.38933    | 0.57054    | 1.09e-94   | 1.00e-06   | OK
# 0.38927    | 0.57051    | 1.03e-94   | 1.00e-06   | OK
# 0.39311    | 0.57243    | 2.22e-93   | 1.00e-06   | OK
# 0.39427    | 0.57301    | 5.48e-93   | 1.00e-06   | OK
# 0.38905    | 0.57040    | 8.69e-95   | 1.00e-06   | OK
# 0.39238    | 0.57206    | 1.23e-93   | 1.00e-06   | OK
# 0.39653    | 0.57414    | 3.26e-92   | 1.00e-06   | OK
# 0.39857    | 0.57516    | 1.58e-91   | 1.00e-06   | OK
# 0.39392    | 0.57283    | 4.17e-93   | 1.00e-06   | OK
# 0.39163    | 0.57169    | 6.84e-94   | 1.00e-06   | OK
# 0.39432    | 0.57304    | 5.72e-93   | 1.00e-06   | OK
# 0.39377    | 0.57276    | 3.72e-93   | 1.00e-06   | OK
# 0.40198    | 0.57686    | 2.24e-90   | 1.00e-06   | OK
# 0.39598    | 0.57386    | 2.10e-92   | 1.00e-06   | OK
# 0.40379    | 0.57777    | 9.30e-90   | 1.00e-06   | OK
# 0.40609    | 0.57892    | 5.75e-89   | 1.00e-06   | OK
# 0.40179    | 0.57677    | 1.94e-90   | 1.00e-06   | OK
# 0.40500    | 0.57838    | 2.41e-89   | 1.00e-06   | OK
# 0.40239    | 0.57707    | 3.11e-90   | 1.00e-06   | OK
# 0.40574    | 0.57874    | 4.33e-89   | 1.00e-06   | OK
# 0.40677    | 0.57926    | 9.79e-89   | 1.00e-06   | OK
# 0.40439    | 0.57807    | 1.49e-89   | 1.00e-06   | OK
# 0.41139    | 0.58157    | 4.33e-87   | 1.00e-06   | OK
# 0.41339    | 0.58257    | 2.28e-86   | 1.00e-06   | OK
# 0.41179    | 0.58177    | 5.98e-87   | 1.00e-06   | OK
# 0.40910    | 0.58043    | 6.52e-88   | 1.00e-06   | OK
# 0.41156    | 0.58165    | 4.95e-87   | 1.00e-06   | OK
# 0.41908    | 0.58542    | 2.64e-84   | 1.00e-06   | OK
# 0.42028    | 0.58601    | 7.23e-84   | 1.00e-06   | OK
# 0.41209    | 0.58192    | 7.63e-87   | 1.00e-06   | OK
# 0.41927    | 0.58551    | 3.09e-84   | 1.00e-06   | OK
# 0.41932    | 0.58554    | 3.21e-84   | 1.00e-06   | OK
# 0.41458    | 0.58317    | 6.29e-86   | 1.00e-06   | OK
# 0.42027    | 0.58601    | 7.21e-84   | 1.00e-06   | OK
# 0.41929    | 0.58552    | 3.14e-84   | 1.00e-06   | OK
# 0.42742    | 0.58959    | 2.12e-81   | 1.00e-06   | OK
# 0.42768    | 0.58972    | 2.62e-81   | 1.00e-06   | OK
# 0.41983    | 0.58579    | 4.97e-84   | 1.00e-06   | OK
# 0.42629    | 0.58902    | 8.76e-82   | 1.00e-06   | OK
# 0.43089    | 0.59132    | 2.93e-80   | 1.00e-06   | OK
# 0.42604    | 0.58889    | 7.18e-82   | 1.00e-06   | OK
# 0.42559    | 0.58867    | 5.11e-82   | 1.00e-06   | OK
# 0.42744    | 0.58960    | 2.16e-81   | 1.00e-06   | OK
# 0.43359    | 0.59267    | 2.14e-79   | 1.00e-06   | OK
# 0.43259    | 0.59217    | 1.04e-79   | 1.00e-06   | OK
# 0.43253    | 0.59214    | 9.88e-80   | 1.00e-06   | OK
# 0.43611    | 0.59393    | 1.29e-78   | 1.00e-06   | OK
# 0.43407    | 0.59291    | 3.03e-79   | 1.00e-06   | OK
# 0.43838    | 0.59507    | 6.47e-78   | 1.00e-06   | OK
# 0.43317    | 0.59246    | 1.58e-79   | 1.00e-06   | OK
# 0.43337    | 0.59256    | 1.82e-79   | 1.00e-06   | OK
# 0.43464    | 0.59320    | 4.52e-79   | 1.00e-06   | OK
# 0.43966    | 0.59571    | 1.58e-77   | 1.00e-06   | OK
# 0.43620    | 0.59398    | 1.38e-78   | 1.00e-06   | OK
# 0.44304    | 0.59740    | 1.68e-76   | 1.00e-06   | OK
# 0.43994    | 0.59584    | 1.91e-77   | 1.00e-06   | OK
# 0.44414    | 0.59795    | 3.71e-76   | 1.00e-06   | OK
# 0.44663    | 0.59919    | 2.06e-75   | 1.00e-06   | OK
# 0.44926    | 0.60051    | 1.36e-74   | 1.00e-06   | OK
# 0.44982    | 0.60079    | 2.03e-74   | 1.00e-06   | OK
# 0.44526    | 0.59851    | 7.96e-76   | 1.00e-06   | OK
# 0.45334    | 0.60254    | 2.38e-73   | 1.00e-06   | OK
# 0.44565    | 0.59870    | 1.03e-75   | 1.00e-06   | OK
# 0.44983    | 0.60079    | 2.05e-74   | 1.00e-06   | OK
# 0.45095    | 0.60135    | 4.49e-74   | 1.00e-06   | OK
# 0.45633    | 0.60404    | 2.10e-72   | 1.00e-06   | OK
# 0.45124    | 0.60150    | 5.51e-74   | 1.00e-06   | OK
# 0.45846    | 0.60511    | 9.61e-72   | 1.00e-06   | OK
# 0.45622    | 0.60398    | 1.97e-72   | 1.00e-06   | OK
# 0.45201    | 0.60188    | 9.49e-74   | 1.00e-06   | OK
# 0.45554    | 0.60364    | 1.19e-72   | 1.00e-06   | OK
# 0.45955    | 0.60565    | 2.12e-71   | 1.00e-06   | OK
# 0.46333    | 0.60754    | 3.28e-70   | 1.00e-06   | OK
# 0.46507    | 0.60841    | 1.17e-69   | 1.00e-06   | OK
# 0.45909    | 0.60542    | 1.55e-71   | 1.00e-06   | OK
# 0.68381    | 0.71751    | 7.24e-13   | 1.00e-06   | OK
# 0.68102    | 0.71654    | 2.66e-13   | 1.00e-06   | OK
# 0.67688    | 0.71494    | 4.69e-14   | 1.00e-06   | OK
# 0.68623    | 0.71836    | 1.79e-12   | 1.00e-06   | OK
# 0.68377    | 0.71750    | 7.18e-13   | 1.00e-06   | OK
# 0.68611    | 0.71831    | 1.71e-12   | 1.00e-06   | OK
# 0.68403    | 0.71759    | 8.12e-13   | 1.00e-06   | OK
# 0.69121    | 0.72016    | 1.17e-11   | 1.00e-06   | OK
# 0.68791    | 0.71896    | 3.27e-12   | 1.00e-06   | OK
# 0.69088    | 0.72004    | 1.02e-11   | 1.00e-06   | OK
# 0.69339    | 0.72103    | 2.93e-11   | 1.00e-06   | OK
# 0.68686    | 0.71858    | 2.22e-12   | 1.00e-06   | OK
# 0.69480    | 0.72162    | 5.45e-11   | 1.00e-06   | OK
# 0.69064    | 0.71995    | 9.32e-12   | 1.00e-06   | OK
# 0.69448    | 0.72149    | 4.82e-11   | 1.00e-06   | OK
# 0.69947    | 0.72362    | 4.76e-10   | 1.00e-06   | OK
# 0.69376    | 0.72119    | 3.47e-11   | 1.00e-06   | OK
# 0.69850    | 0.72320    | 3.08e-10   | 1.00e-06   | OK
# 0.70023    | 0.72395    | 6.81e-10   | 1.00e-06   | OK
# 0.69950    | 0.72363    | 4.81e-10   | 1.00e-06   | OK
# 0.69870    | 0.72329    | 3.38e-10   | 1.00e-06   | OK
# 0.69620    | 0.72222    | 1.07e-10   | 1.00e-06   | OK
# 0.69701    | 0.72257    | 1.56e-10   | 1.00e-06   | OK
# 0.69972    | 0.72373    | 5.33e-10   | 1.00e-06   | OK
# 0.70112    | 0.72436    | 1.05e-09   | 1.00e-06   | OK
# 0.70083    | 0.72421    | 8.93e-10   | 1.00e-06   | OK
# 0.70128    | 0.72445    | 1.15e-09   | 1.00e-06   | OK
# 0.71033    | 0.72936    | 1.42e-07   | 1.00e-06   | OK
# 0.70541    | 0.72665    | 1.07e-08   | 1.00e-06   | OK
# 0.70482    | 0.72633    | 7.87e-09   | 1.00e-06   | OK
# 0.71102    | 0.72976    | 2.06e-07   | 1.00e-06   | OK
# 0.71100    | 0.72975    | 2.04e-07   | 1.00e-06   | OK
# 0.71217    | 0.73042    | 3.78e-07   | 1.00e-06   | OK
# 0.71287    | 0.73082    | 5.46e-07   | 1.00e-06   | OK
# 0.71855    | 0.73390    | 8.80e-06   | 1.00e-06   | VIOLATED
# 0.71598    | 0.73254    | 2.59e-06   | 1.00e-06   | VIOLATED
# 0.72038    | 0.73487    | 2.05e-05   | 1.00e-06   | VIOLATED
# 0.71796    | 0.73359    | 6.61e-06   | 1.00e-06   | VIOLATED
# 0.71553    | 0.73230    | 2.11e-06   | 1.00e-06   | VIOLATED
# 0.71431    | 0.73164    | 1.13e-06   | 1.00e-06   | VIOLATED
# 0.71489    | 0.73196    | 1.54e-06   | 1.00e-06   | VIOLATED
# 0.71973    | 0.73452    | 1.51e-05   | 1.00e-06   | VIOLATED
# 0.72256    | 0.73600    | 5.48e-05   | 1.00e-06   | VIOLATED
# 0.72406    | 0.73677    | 1.05e-04   | 1.00e-06   | VIOLATED
# 0.72084    | 0.73511    | 2.54e-05   | 1.00e-06   | VIOLATED
# 0.71986    | 0.73460    | 1.63e-05   | 1.00e-06   | VIOLATED
# 0.72383    | 0.73665    | 9.46e-05   | 1.00e-06   | VIOLATED
# 0.73112    | 0.74043    | 2.29e-03   | 1.00e-06   | VIOLATED
# 0.73200    | 0.74090    | 3.40e-03   | 1.00e-06   | VIOLATED
# 0.72505    | 0.73727    | 1.61e-04   | 1.00e-06   | VIOLATED
# 0.72863    | 0.73910    | 7.50e-04   | 1.00e-06   | VIOLATED
# 0.73261    | 0.74123    | 4.53e-03   | 1.00e-06   | VIOLATED
# 0.72802    | 0.73879    | 5.74e-04   | 1.00e-06   | VIOLATED
# 0.72785    | 0.73870    | 5.35e-04   | 1.00e-06   | VIOLATED
# 0.73333    | 0.74162    | 6.26e-03   | 1.00e-06   | VIOLATED
# 0.73626    | 0.74319    | 2.22e-02   | 1.00e-06   | VIOLATED
# 0.73479    | 0.74240    | 1.17e-02   | 1.00e-06   | VIOLATED
# 0.74003    | 0.74534    | 1.10e-01   | 1.00e-06   | VIOLATED
# 0.73616    | 0.74313    | 2.11e-02   | 1.00e-06   | VIOLATED
# 0.73908    | 0.74480    | 7.52e-02   | 1.00e-06   | VIOLATED
# 0.74188    | 0.74638    | 2.10e-01   | 1.00e-06   | VIOLATED
# 0.74092    | 0.74584    | 1.50e-01   | 1.00e-06   | VIOLATED
# 0.74039    | 0.74554    | 1.26e-01   | 1.00e-06   | VIOLATED
# 0.74429    | 0.74774    | 4.31e-01   | 1.00e-06   | VIOLATED
# 0.74268    | 0.74682    | 2.72e-01   | 1.00e-06   | VIOLATED
# 0.74931    | 0.75050    | 6.90e-01   | 1.00e-06   | VIOLATED
# 0.74161    | 0.74623    | 1.92e-01   | 1.00e-06   | VIOLATED
# 0.74330    | 0.74718    | 3.34e-01   | 1.00e-06   | VIOLATED
# 0.74385    | 0.74749    | 3.87e-01   | 1.00e-06   | VIOLATED
# 0.75215    | 0.75175    | -3.93e-13  | 1.00e-06   | OK
# 0.74703    | 0.74927    | 7.42e-01   | 1.00e-06   | VIOLATED
# 0.75334    | 0.75175    | -1.55e-12  | 1.00e-06   | OK
# 0.75379    | 0.75175    | -1.99e-12  | 1.00e-06   | OK
#
# =================================================================
# WARNING: Seller inequality violations detected
# - Potential causes:
#   1. Boundary effects in seller offer strategies
#   2. Discontinuities in seller virtual valuations
#   3. Numerical instability in high-density regions
# =================================================================

# %%
# ----------------------------------------------------------
# Robust Equilibrium Strategy Preservation from Section 4.5
# ----------------------------------------------------------

import pandas as pd
import pickle
from pathlib import Path

# -----------------------------------------
# Necessary Integrity Checks
# -----------------------------------------

def validate_equilibrium_dict(buyer_dict, seller_dict):
    """Ensure data integrity for downstream systems"""
    if not all(isinstance(v, float) for v in buyer_dict.keys()):
        raise ValueError("Buyer keys must be floats")
    if not all(isinstance(v, float) for v in seller_dict.keys()):
        raise ValueError("Seller keys must be floats")
    return True

# ---------------------------------------------------------------
# Algorithmic Formalization of Method 9 (Strategy Serialization)
# ---------------------------------------------------------------

try:
    validate_equilibrium_dict(extended_buyer_eq, extended_seller_eq)
    
    # ------------------------------------------------------------
    # Encode Buyer Strategies as Ordered Pairs from Equation (26) 
    # ------------------------------------------------------------
    
    df_buyers = pd.DataFrame(
        sorted(extended_buyer_eq.items(), key=lambda x: x[0]),
        columns=["Buyer Valuation", "Bid B(vb)"]
    )
    
    # ---------------------------------------------------------
    # Utility Calculation for Sellers from the End of Method 9
    # ---------------------------------------------------------
    
    df_buyers["Buyer Utility"] = df_buyers["Buyer Valuation"] - df_buyers["Bid B(vb)"]
    
    # -------------------------------------------------------------
    # Encode Seller Strategies as Ordered Pairs from Equation (27) 
    # -------------------------------------------------------------
    
    df_sellers = pd.DataFrame(
        sorted(extended_seller_eq.items(), key=lambda x: x[0]),
        columns=["Seller Valuation", "Offer S(vs)"]
    )
    
    # ---------------------------------------------------------
    # Utility Calculation for Sellers from the End of Method 9
    # ---------------------------------------------------------
    
    df_sellers["Seller Utility"] = df_sellers["Offer S(vs)"] - df_sellers["Seller Valuation"]

except Exception as e:
    raise RuntimeError(f"Data validation failed: {str(e)}") from e

# -----------------------------------------------------------------------------------------------
# Save Data, Allows Us to Upload Equilibrium Bids and Offers Data to the "Market Maker" Workbook
# -----------------------------------------------------------------------------------------------

EQUILIBRIUM_STRUCTURE = {
    "buyers": {
        "columns": ["Buyer Valuation", "Bid B(vb)", "Buyer Utility"],
        "data": df_buyers.values.tolist()
    },
    "sellers": {
        "columns": ["Seller Valuation", "Offer S(vs)", "Seller Utility"],
        "data": df_sellers.values.tolist()
    }
}

def save_equilibrium_data(data_dict):
    """Preserve exact structure for legacy systems"""
    try:
        with open("equilibrium_strategies_constrained.pkl", "wb") as f:
            pickle.dump(data_dict, f, protocol=4)
        return Path("equilibrium_strategies_constrained.pkl").stat().st_size
    except Exception as e:
        raise IOError(f"Pickle save failed: {str(e)}") from e

# ----------------------------------------------------------------------------------------
# Print Strategy Conservation of Equilibrium Bids and Offers B*(vb) and S*(vs) (Figure 8)
# ----------------------------------------------------------------------------------------

print("\nConstrained Equilibrium Strategies:\n")
print(f"Buyer Strategies B(vb) | {len(df_buyers)} agents")
print(df_buyers.to_string(index=False, float_format=lambda x: f"{x:.5f}"))
print("\n" + "-"*60)
print(f"\nSeller Strategies S(vs) | {len(df_sellers)} agents")
print(df_sellers.to_string(index=False, float_format=lambda x: f"{x:.5f}"))

file_size = save_equilibrium_data(EQUILIBRIUM_STRUCTURE)
print(f"\nStrategies saved successfully ({file_size/1024:.1f} KB)")
# Out:
# Constrained Equilibrium Strategies:
#
# Buyer Strategies B(vb) | 1000 agents
#  Buyer Valuation  Bid B(vb)  Buyer Utility
#          0.00000    0.00000        0.00000
#          0.00100    0.00100       -0.00000
#          0.00200    0.00200       -0.00000
#          0.00300    0.00300        0.00000
#          0.00400    0.00400        0.00000
